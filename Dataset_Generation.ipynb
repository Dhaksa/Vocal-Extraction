# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhaksa/Vocal-Extraction/blob/main/Dataset_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
import zipfile
import shutil

# %%
# Mount Google Drive (only needed if running in Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to save directly in Google Drive
drive_path = "/content/drive/MyDrive/New/Clean-vocals"
os.makedirs(drive_path, exist_ok=True)

# Paths to ZIP files
male_zip = "/content/drive/MyDrive/CP/ta_in_male.zip"
female_zip = "/content/drive/MyDrive/CP/ta_in_female.zip"

def extract_and_rename(zip_path, prefix, num_files):
    """Extract ZIP, pick 'num_files' randomly, rename, and save to drive_path."""
    temp_extract = "temp_extracted"

    # Extract files
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(temp_extract)

    # Get all WAV files
    all_files = [f for f in os.listdir(temp_extract) if f.endswith(".wav")]

    # Randomly select required number of files
    selected_files = random.sample(all_files, num_files)

    # Rename and move files to Google Drive
    for idx, filename in enumerate(selected_files, start=1):
        new_name = f"{prefix}_{idx:03d}.wav"
        shutil.move(os.path.join(temp_extract, filename), os.path.join(drive_path, new_name))

    # Clean up temp folder
    shutil.rmtree(temp_extract)

# Process both male and female ZIPs
extract_and_rename(male_zip, "male", 20)
extract_and_rename(female_zip, "female", 20)

print(f"Renaming and selection complete! Files saved in '{drive_path}'")
# Out:
# Renaming and selection complete! Files saved in '/content/drive/MyDrive/New/Clean-vocals'

# %%
# !pip install musdb
# Out:
# Requirement already satisfied: musdb in /usr/local/lib/python3.11/dist-packages (0.4.2)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.11/dist-packages (from musdb) (1.26.4)
# Requirement already satisfied: stempeg>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from musdb) (0.2.3)
# Requirement already satisfied: pyaml in /usr/local/lib/python3.11/dist-packages (from musdb) (25.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from musdb) (4.67.1)
# Requirement already satisfied: ffmpeg-python>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from stempeg>=0.2.3->musdb) (0.2.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from pyaml->musdb) (6.0.2)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from ffmpeg-python>=0.2.0->stempeg>=0.2.3->musdb) (1.0.0)

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Set path inside Google Drive
drive_path = "/content/drive/MyDrive/MUSDB18_Instrumentals"
os.makedirs(drive_path, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import musdb
import os
import soundfile as sf  # Import soundfile for writing audio

# Set path to store MUSDB18 dataset
musdb_path = "/content/musdb18_dataset"  # Local path for processing
os.makedirs(musdb_path, exist_ok=True)

# Set path inside Google Drive
drive_path = "/content/drive/MyDrive/MUSDB18_Instrumentals"
os.makedirs(drive_path, exist_ok=True)

# Download and extract the dataset
mus = musdb.DB(root=musdb_path, subsets="train", download=True)

# Extract instrumental (background music) and save to Google Drive
for i, track in enumerate(mus.tracks):
    instrumental = track.audio[:, 0]  # Convert stereo to mono
    file_path = os.path.join(drive_path, f"musdb_bg_{i}.wav")

    # Write the audio file
    sf.write(file_path, instrumental, track.rate)

    print(f"Saved: {file_path}")

print("Extracted MUSDB18 instrumentals successfully & saved to Google Drive!")
# Out:
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_0.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_1.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_2.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_3.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_4.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_5.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_6.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_7.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_8.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_9.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_10.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_11.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_12.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_13.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_14.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_15.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_16.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_17.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_18.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_19.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_20.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_21.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_22.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_23.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_24.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_25.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_26.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_27.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_28.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_29.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_30.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_31.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_32.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_33.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_34.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_35.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_36.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_37.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_38.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_39.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_40.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_41.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_42.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_43.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_44.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_45.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_46.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_47.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_48.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_49.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_50.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_51.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_52.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_53.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_54.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_55.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_56.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_57.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_58.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_59.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_60.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_61.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_62.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_63.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_64.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_65.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_66.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_67.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_68.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_69.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_70.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_71.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_72.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_73.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_74.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_75.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_76.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_77.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_78.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_79.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_80.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_81.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_82.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_83.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_84.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_85.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_86.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_87.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_88.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_89.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_90.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_91.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_92.wav
# Saved: /content/drive/MyDrive/MUSDB18_Instrumentals/musdb_bg_93.wav
# Extracted MUSDB18 instrumentals successfully & saved to Google Drive!

# %%
# !pip install librosa numpy pydub soundfile
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.10.2.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.61.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lazy-loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)

# %%
import librosa
import numpy as np
import soundfile as sf
import os
from itertools import cycle

# Paths
drive_path = "/content/drive/MyDrive/CP/MUSDB18_Instrumentals"  # Background music path
vocals_path = "/content/drive/MyDrive/New/Clean-vocals"  # Path where clean vocals are stored
output_path = "/content/drive/MyDrive/Augmented - Audios"  # Save augmented audio
os.makedirs(output_path, exist_ok=True)

# List all vocal and instrumental files
vocal_files = sorted([f for f in os.listdir(vocals_path) if f.endswith(".wav")])
music_files = sorted([f for f in os.listdir(drive_path) if f.endswith(".wav")])

# Use cycle to loop through background music continuously
music_cycle = cycle(music_files)

def change_pitch(y, sr, n_steps):
    """Change the pitch of the audio."""
    return librosa.effects.pitch_shift(y, sr=sr, n_steps=n_steps)

def change_volume(y, gain_db):
    """Change the volume by a given gain in dB."""
    return y * (10**(gain_db / 20))

def mix_audio(vocals, music, vocal_vol=1.0, music_vol=0.5):
    """Mix vocals and music with specified volume adjustments."""
    vocals = change_volume(vocals, vocal_vol)
    music = change_volume(music, music_vol)
    return np.clip(vocals + music, -1.0, 1.0)  # Normalize to prevent clipping

def add_noise(audio, noise_type="white", noise_level=0.1):
    """Add different types of noise to the audio."""
    noise = np.random.randn(len(audio))  # White noise by default

    if noise_type == "pink":
        # Generate pink noise (1/f noise)
        uneven = len(noise) % 2
        fft = np.fft.rfft(noise)
        frequencies = np.fft.rfftfreq(len(noise))
        fft = fft / (frequencies + 1e-4)  # Reduce higher frequencies
        noise = np.fft.irfft(fft)
        if uneven:
            noise = noise[:-1]
    elif noise_type == "gaussian":
        noise = np.random.normal(0, 1, len(audio))  # Gaussian noise

    # Ensure noise length matches audio length
    if len(noise) < len(audio):
        noise = np.pad(noise, (0, len(audio) - len(noise)), mode='constant')  # Pad with zeros
    else:
        noise = noise[:len(audio)]  # Trim extra length

    noise = noise / (np.max(np.abs(noise)) + 1e-6)  # Normalize noise
    return np.clip(audio + noise * noise_level, -1.0, 1.0)  # Scale noise intensity

# Process vocals in order, cycling through noise types
noise_types = ["white", "pink", "gaussian"]
for i, vocal_file in enumerate(vocal_files):
    vocal_path = os.path.join(vocals_path, vocal_file)
    vocal, sr = librosa.load(vocal_path, sr=44100)

    # Get a background music track in a cyclic manner
    music_file = next(music_cycle)
    music_path = os.path.join(drive_path, music_file)
    music, _ = librosa.load(music_path, sr=44100)

    # Make sure both audio files are the same length
    min_length = min(len(vocal), len(music))
    vocal, music = vocal[:min_length], music[:min_length]

    # Assign one type of noise per vocal file (cycling through)
    noise_type = noise_types[i % len(noise_types)]

    # Generate variations
    for pitch_shift in [-2, 0, 2]:  # Lower, original, and higher pitch
        for vocal_vol in [-3, 0, 3]:  # Lower, normal, and boosted volume
            for music_vol in [-5, -3, 0]:  # Background music volume levels
                # Apply transformations
                augmented_vocal = change_pitch(vocal, sr, pitch_shift)
                augmented_vocal = add_noise(augmented_vocal, noise_type, noise_level=0.05)  # Lower noise level
                augmented_music = change_pitch(music, sr, pitch_shift)
                mixed_audio = mix_audio(augmented_vocal, augmented_music, vocal_vol, music_vol)

                # Save file
                new_filename = f"{vocal_file[:-4]}_{music_file[:-4]}_p{pitch_shift}_vv{vocal_vol}_mv{music_vol}_n{noise_type}.wav"
                sf.write(os.path.join(output_path, new_filename), mixed_audio, sr)
                print(f"Saved: {new_filename}")

print("Augmentation completed & saved to Google Drive!")
# Out:
# Saved: female_001_musdb_bg_0_p-2_vv-3_mv-5_nwhite.wav
# Saved: female_001_musdb_bg_0_p-2_vv-3_mv-3_nwhite.wav
# Saved: female_001_musdb_bg_0_p-2_vv-3_mv0_nwhite.wav
# Saved: female_001_musdb_bg_0_p-2_vv0_mv-5_nwhite.wav
# Saved: female_001_musdb_bg_0_p-2_vv0_mv-3_nwhite.wav
# Saved: female_001_musdb_bg_0_p-2_vv0_mv0_nwhite.wav
# Saved: female_001_musdb_bg_0_p-2_vv3_mv-5_nwhite.wav
# Saved: female_001_musdb_bg_0_p-2_vv3_mv-3_nwhite.wav
# Saved: female_001_musdb_bg_0_p-2_vv3_mv0_nwhite.wav
# Saved: female_001_musdb_bg_0_p0_vv-3_mv-5_nwhite.wav
# Saved: female_001_musdb_bg_0_p0_vv-3_mv-3_nwhite.wav
# Saved: female_001_musdb_bg_0_p0_vv-3_mv0_nwhite.wav
# Saved: female_001_musdb_bg_0_p0_vv0_mv-5_nwhite.wav
# Saved: female_001_musdb_bg_0_p0_vv0_mv-3_nwhite.wav
# Saved: female_001_musdb_bg_0_p0_vv0_mv0_nwhite.wav
# Saved: female_001_musdb_bg_0_p0_vv3_mv-5_nwhite.wav
# Saved: female_001_musdb_bg_0_p0_vv3_mv-3_nwhite.wav
# Saved: female_001_musdb_bg_0_p0_vv3_mv0_nwhite.wav
# Saved: female_001_musdb_bg_0_p2_vv-3_mv-5_nwhite.wav
# Saved: female_001_musdb_bg_0_p2_vv-3_mv-3_nwhite.wav
# Saved: female_001_musdb_bg_0_p2_vv-3_mv0_nwhite.wav
# Saved: female_001_musdb_bg_0_p2_vv0_mv-5_nwhite.wav
# Saved: female_001_musdb_bg_0_p2_vv0_mv-3_nwhite.wav
# Saved: female_001_musdb_bg_0_p2_vv0_mv0_nwhite.wav
# Saved: female_001_musdb_bg_0_p2_vv3_mv-5_nwhite.wav
# Saved: female_001_musdb_bg_0_p2_vv3_mv-3_nwhite.wav
# Saved: female_001_musdb_bg_0_p2_vv3_mv0_nwhite.wav
# Saved: female_002_musdb_bg_1_p-2_vv-3_mv-5_npink.wav
# Saved: female_002_musdb_bg_1_p-2_vv-3_mv-3_npink.wav
# Saved: female_002_musdb_bg_1_p-2_vv-3_mv0_npink.wav
# Saved: female_002_musdb_bg_1_p-2_vv0_mv-5_npink.wav
# Saved: female_002_musdb_bg_1_p-2_vv0_mv-3_npink.wav
# Saved: female_002_musdb_bg_1_p-2_vv0_mv0_npink.wav
# Saved: female_002_musdb_bg_1_p-2_vv3_mv-5_npink.wav
# Saved: female_002_musdb_bg_1_p-2_vv3_mv-3_npink.wav
# Saved: female_002_musdb_bg_1_p-2_vv3_mv0_npink.wav
# Saved: female_002_musdb_bg_1_p0_vv-3_mv-5_npink.wav
# Saved: female_002_musdb_bg_1_p0_vv-3_mv-3_npink.wav
# Saved: female_002_musdb_bg_1_p0_vv-3_mv0_npink.wav
# Saved: female_002_musdb_bg_1_p0_vv0_mv-5_npink.wav
# Saved: female_002_musdb_bg_1_p0_vv0_mv-3_npink.wav
# Saved: female_002_musdb_bg_1_p0_vv0_mv0_npink.wav
# Saved: female_002_musdb_bg_1_p0_vv3_mv-5_npink.wav
# Saved: female_002_musdb_bg_1_p0_vv3_mv-3_npink.wav
# Saved: female_002_musdb_bg_1_p0_vv3_mv0_npink.wav
# Saved: female_002_musdb_bg_1_p2_vv-3_mv-5_npink.wav
# Saved: female_002_musdb_bg_1_p2_vv-3_mv-3_npink.wav
# Saved: female_002_musdb_bg_1_p2_vv-3_mv0_npink.wav
# Saved: female_002_musdb_bg_1_p2_vv0_mv-5_npink.wav
# Saved: female_002_musdb_bg_1_p2_vv0_mv-3_npink.wav
# Saved: female_002_musdb_bg_1_p2_vv0_mv0_npink.wav
# Saved: female_002_musdb_bg_1_p2_vv3_mv-5_npink.wav
# Saved: female_002_musdb_bg_1_p2_vv3_mv-3_npink.wav
# Saved: female_002_musdb_bg_1_p2_vv3_mv0_npink.wav
# Saved: female_003_musdb_bg_10_p-2_vv-3_mv-5_ngaussian.wav
# Saved: female_003_musdb_bg_10_p-2_vv-3_mv-3_ngaussian.wav
# Saved: female_003_musdb_bg_10_p-2_vv-3_mv0_ngaussian.wav
# Saved: female_003_musdb_bg_10_p-2_vv0_mv-5_ngaussian.wav
# Saved: female_003_musdb_bg_10_p-2_vv0_mv-3_ngaussian.wav
# Saved: female_003_musdb_bg_10_p-2_vv0_mv0_ngaussian.wav
# Saved: female_003_musdb_bg_10_p-2_vv3_mv-5_ngaussian.wav
# Saved: female_003_musdb_bg_10_p-2_vv3_mv-3_ngaussian.wav
# Saved: female_003_musdb_bg_10_p-2_vv3_mv0_ngaussian.wav
# Saved: female_003_musdb_bg_10_p0_vv-3_mv-5_ngaussian.wav
# Saved: female_003_musdb_bg_10_p0_vv-3_mv-3_ngaussian.wav
# Saved: female_003_musdb_bg_10_p0_vv-3_mv0_ngaussian.wav
# Saved: female_003_musdb_bg_10_p0_vv0_mv-5_ngaussian.wav
# Saved: female_003_musdb_bg_10_p0_vv0_mv-3_ngaussian.wav
# Saved: female_003_musdb_bg_10_p0_vv0_mv0_ngaussian.wav
# Saved: female_003_musdb_bg_10_p0_vv3_mv-5_ngaussian.wav
# Saved: female_003_musdb_bg_10_p0_vv3_mv-3_ngaussian.wav
# Saved: female_003_musdb_bg_10_p0_vv3_mv0_ngaussian.wav
# Saved: female_003_musdb_bg_10_p2_vv-3_mv-5_ngaussian.wav
# Saved: female_003_musdb_bg_10_p2_vv-3_mv-3_ngaussian.wav
# Saved: female_003_musdb_bg_10_p2_vv-3_mv0_ngaussian.wav
# Saved: female_003_musdb_bg_10_p2_vv0_mv-5_ngaussian.wav
# Saved: female_003_musdb_bg_10_p2_vv0_mv-3_ngaussian.wav
# Saved: female_003_musdb_bg_10_p2_vv0_mv0_ngaussian.wav
# Saved: female_003_musdb_bg_10_p2_vv3_mv-5_ngaussian.wav
# Saved: female_003_musdb_bg_10_p2_vv3_mv-3_ngaussian.wav
# Saved: female_003_musdb_bg_10_p2_vv3_mv0_ngaussian.wav
# Saved: female_004_musdb_bg_11_p-2_vv-3_mv-5_nwhite.wav
# Saved: female_004_musdb_bg_11_p-2_vv-3_mv-3_nwhite.wav
# Saved: female_004_musdb_bg_11_p-2_vv-3_mv0_nwhite.wav
# Saved: female_004_musdb_bg_11_p-2_vv0_mv-5_nwhite.wav
# Saved: female_004_musdb_bg_11_p-2_vv0_mv-3_nwhite.wav
# Saved: female_004_musdb_bg_11_p-2_vv0_mv0_nwhite.wav
# Saved: female_004_musdb_bg_11_p-2_vv3_mv-5_nwhite.wav
# Saved: female_004_musdb_bg_11_p-2_vv3_mv-3_nwhite.wav
# Saved: female_004_musdb_bg_11_p-2_vv3_mv0_nwhite.wav
# Saved: female_004_musdb_bg_11_p0_vv-3_mv-5_nwhite.wav
# Saved: female_004_musdb_bg_11_p0_vv-3_mv-3_nwhite.wav
# Saved: female_004_musdb_bg_11_p0_vv-3_mv0_nwhite.wav
# Saved: female_004_musdb_bg_11_p0_vv0_mv-5_nwhite.wav
# Saved: female_004_musdb_bg_11_p0_vv0_mv-3_nwhite.wav
# Saved: female_004_musdb_bg_11_p0_vv0_mv0_nwhite.wav
# Saved: female_004_musdb_bg_11_p0_vv3_mv-5_nwhite.wav
# Saved: female_004_musdb_bg_11_p0_vv3_mv-3_nwhite.wav
# Saved: female_004_musdb_bg_11_p0_vv3_mv0_nwhite.wav
# Saved: female_004_musdb_bg_11_p2_vv-3_mv-5_nwhite.wav
# Saved: female_004_musdb_bg_11_p2_vv-3_mv-3_nwhite.wav
# Saved: female_004_musdb_bg_11_p2_vv-3_mv0_nwhite.wav
# Saved: female_004_musdb_bg_11_p2_vv0_mv-5_nwhite.wav
# Saved: female_004_musdb_bg_11_p2_vv0_mv-3_nwhite.wav
# Saved: female_004_musdb_bg_11_p2_vv0_mv0_nwhite.wav
# Saved: female_004_musdb_bg_11_p2_vv3_mv-5_nwhite.wav
# Saved: female_004_musdb_bg_11_p2_vv3_mv-3_nwhite.wav
# Saved: female_004_musdb_bg_11_p2_vv3_mv0_nwhite.wav
# Saved: female_005_musdb_bg_12_p-2_vv-3_mv-5_npink.wav
# Saved: female_005_musdb_bg_12_p-2_vv-3_mv-3_npink.wav
# Saved: female_005_musdb_bg_12_p-2_vv-3_mv0_npink.wav
# Saved: female_005_musdb_bg_12_p-2_vv0_mv-5_npink.wav
# Saved: female_005_musdb_bg_12_p-2_vv0_mv-3_npink.wav
# Saved: female_005_musdb_bg_12_p-2_vv0_mv0_npink.wav
# Saved: female_005_musdb_bg_12_p-2_vv3_mv-5_npink.wav
# Saved: female_005_musdb_bg_12_p-2_vv3_mv-3_npink.wav
# Saved: female_005_musdb_bg_12_p-2_vv3_mv0_npink.wav
# Saved: female_005_musdb_bg_12_p0_vv-3_mv-5_npink.wav
# Saved: female_005_musdb_bg_12_p0_vv-3_mv-3_npink.wav
# Saved: female_005_musdb_bg_12_p0_vv-3_mv0_npink.wav
# Saved: female_005_musdb_bg_12_p0_vv0_mv-5_npink.wav
# Saved: female_005_musdb_bg_12_p0_vv0_mv-3_npink.wav
# Saved: female_005_musdb_bg_12_p0_vv0_mv0_npink.wav
# Saved: female_005_musdb_bg_12_p0_vv3_mv-5_npink.wav
# Saved: female_005_musdb_bg_12_p0_vv3_mv-3_npink.wav
# Saved: female_005_musdb_bg_12_p0_vv3_mv0_npink.wav
# Saved: female_005_musdb_bg_12_p2_vv-3_mv-5_npink.wav
# Saved: female_005_musdb_bg_12_p2_vv-3_mv-3_npink.wav
# Saved: female_005_musdb_bg_12_p2_vv-3_mv0_npink.wav
# Saved: female_005_musdb_bg_12_p2_vv0_mv-5_npink.wav
# Saved: female_005_musdb_bg_12_p2_vv0_mv-3_npink.wav
# Saved: female_005_musdb_bg_12_p2_vv0_mv0_npink.wav
# Saved: female_005_musdb_bg_12_p2_vv3_mv-5_npink.wav
# Saved: female_005_musdb_bg_12_p2_vv3_mv-3_npink.wav
# Saved: female_005_musdb_bg_12_p2_vv3_mv0_npink.wav
# Saved: female_006_musdb_bg_13_p-2_vv-3_mv-5_ngaussian.wav
# Saved: female_006_musdb_bg_13_p-2_vv-3_mv-3_ngaussian.wav
# Saved: female_006_musdb_bg_13_p-2_vv-3_mv0_ngaussian.wav
# Saved: female_006_musdb_bg_13_p-2_vv0_mv-5_ngaussian.wav
# Saved: female_006_musdb_bg_13_p-2_vv0_mv-3_ngaussian.wav
# Saved: female_006_musdb_bg_13_p-2_vv0_mv0_ngaussian.wav
# Saved: female_006_musdb_bg_13_p-2_vv3_mv-5_ngaussian.wav
# Saved: female_006_musdb_bg_13_p-2_vv3_mv-3_ngaussian.wav
# Saved: female_006_musdb_bg_13_p-2_vv3_mv0_ngaussian.wav
# Saved: female_006_musdb_bg_13_p0_vv-3_mv-5_ngaussian.wav
# Saved: female_006_musdb_bg_13_p0_vv-3_mv-3_ngaussian.wav
# Saved: female_006_musdb_bg_13_p0_vv-3_mv0_ngaussian.wav
# Saved: female_006_musdb_bg_13_p0_vv0_mv-5_ngaussian.wav
# Saved: female_006_musdb_bg_13_p0_vv0_mv-3_ngaussian.wav
# Saved: female_006_musdb_bg_13_p0_vv0_mv0_ngaussian.wav
# Saved: female_006_musdb_bg_13_p0_vv3_mv-5_ngaussian.wav
# Saved: female_006_musdb_bg_13_p0_vv3_mv-3_ngaussian.wav
# Saved: female_006_musdb_bg_13_p0_vv3_mv0_ngaussian.wav
# Saved: female_006_musdb_bg_13_p2_vv-3_mv-5_ngaussian.wav
# Saved: female_006_musdb_bg_13_p2_vv-3_mv-3_ngaussian.wav
# Saved: female_006_musdb_bg_13_p2_vv-3_mv0_ngaussian.wav
# Saved: female_006_musdb_bg_13_p2_vv0_mv-5_ngaussian.wav
# Saved: female_006_musdb_bg_13_p2_vv0_mv-3_ngaussian.wav
# Saved: female_006_musdb_bg_13_p2_vv0_mv0_ngaussian.wav
# Saved: female_006_musdb_bg_13_p2_vv3_mv-5_ngaussian.wav
# Saved: female_006_musdb_bg_13_p2_vv3_mv-3_ngaussian.wav
# Saved: female_006_musdb_bg_13_p2_vv3_mv0_ngaussian.wav
# Saved: female_007_musdb_bg_14_p-2_vv-3_mv-5_nwhite.wav
# Saved: female_007_musdb_bg_14_p-2_vv-3_mv-3_nwhite.wav
# Saved: female_007_musdb_bg_14_p-2_vv-3_mv0_nwhite.wav
# Saved: female_007_musdb_bg_14_p-2_vv0_mv-5_nwhite.wav
# Saved: female_007_musdb_bg_14_p-2_vv0_mv-3_nwhite.wav
# Saved: female_007_musdb_bg_14_p-2_vv0_mv0_nwhite.wav
# Saved: female_007_musdb_bg_14_p-2_vv3_mv-5_nwhite.wav
# Saved: female_007_musdb_bg_14_p-2_vv3_mv-3_nwhite.wav
# Saved: female_007_musdb_bg_14_p-2_vv3_mv0_nwhite.wav
# Saved: female_007_musdb_bg_14_p0_vv-3_mv-5_nwhite.wav
# Saved: female_007_musdb_bg_14_p0_vv-3_mv-3_nwhite.wav
# Saved: female_007_musdb_bg_14_p0_vv-3_mv0_nwhite.wav
# Saved: female_007_musdb_bg_14_p0_vv0_mv-5_nwhite.wav
# Saved: female_007_musdb_bg_14_p0_vv0_mv-3_nwhite.wav
# Saved: female_007_musdb_bg_14_p0_vv0_mv0_nwhite.wav
# Saved: female_007_musdb_bg_14_p0_vv3_mv-5_nwhite.wav
# Saved: female_007_musdb_bg_14_p0_vv3_mv-3_nwhite.wav
# Saved: female_007_musdb_bg_14_p0_vv3_mv0_nwhite.wav
# Saved: female_007_musdb_bg_14_p2_vv-3_mv-5_nwhite.wav
# Saved: female_007_musdb_bg_14_p2_vv-3_mv-3_nwhite.wav
# Saved: female_007_musdb_bg_14_p2_vv-3_mv0_nwhite.wav
# Saved: female_007_musdb_bg_14_p2_vv0_mv-5_nwhite.wav
# Saved: female_007_musdb_bg_14_p2_vv0_mv-3_nwhite.wav
# Saved: female_007_musdb_bg_14_p2_vv0_mv0_nwhite.wav
# Saved: female_007_musdb_bg_14_p2_vv3_mv-5_nwhite.wav
# Saved: female_007_musdb_bg_14_p2_vv3_mv-3_nwhite.wav
# Saved: female_007_musdb_bg_14_p2_vv3_mv0_nwhite.wav
# Saved: female_008_musdb_bg_15_p-2_vv-3_mv-5_npink.wav
# Saved: female_008_musdb_bg_15_p-2_vv-3_mv-3_npink.wav
# Saved: female_008_musdb_bg_15_p-2_vv-3_mv0_npink.wav
# Saved: female_008_musdb_bg_15_p-2_vv0_mv-5_npink.wav
# Saved: female_008_musdb_bg_15_p-2_vv0_mv-3_npink.wav
# Saved: female_008_musdb_bg_15_p-2_vv0_mv0_npink.wav
# Saved: female_008_musdb_bg_15_p-2_vv3_mv-5_npink.wav
# Saved: female_008_musdb_bg_15_p-2_vv3_mv-3_npink.wav
# Saved: female_008_musdb_bg_15_p-2_vv3_mv0_npink.wav
# Saved: female_008_musdb_bg_15_p0_vv-3_mv-5_npink.wav
# Saved: female_008_musdb_bg_15_p0_vv-3_mv-3_npink.wav
# Saved: female_008_musdb_bg_15_p0_vv-3_mv0_npink.wav
# Saved: female_008_musdb_bg_15_p0_vv0_mv-5_npink.wav
# Saved: female_008_musdb_bg_15_p0_vv0_mv-3_npink.wav
# Saved: female_008_musdb_bg_15_p0_vv0_mv0_npink.wav
# Saved: female_008_musdb_bg_15_p0_vv3_mv-5_npink.wav
# Saved: female_008_musdb_bg_15_p0_vv3_mv-3_npink.wav
# Saved: female_008_musdb_bg_15_p0_vv3_mv0_npink.wav
# Saved: female_008_musdb_bg_15_p2_vv-3_mv-5_npink.wav
# Saved: female_008_musdb_bg_15_p2_vv-3_mv-3_npink.wav
# Saved: female_008_musdb_bg_15_p2_vv-3_mv0_npink.wav
# Saved: female_008_musdb_bg_15_p2_vv0_mv-5_npink.wav
# Saved: female_008_musdb_bg_15_p2_vv0_mv-3_npink.wav
# Saved: female_008_musdb_bg_15_p2_vv0_mv0_npink.wav
# Saved: female_008_musdb_bg_15_p2_vv3_mv-5_npink.wav
# Saved: female_008_musdb_bg_15_p2_vv3_mv-3_npink.wav
# Saved: female_008_musdb_bg_15_p2_vv3_mv0_npink.wav
# Saved: female_009_musdb_bg_16_p-2_vv-3_mv-5_ngaussian.wav
# Saved: female_009_musdb_bg_16_p-2_vv-3_mv-3_ngaussian.wav
# Saved: female_009_musdb_bg_16_p-2_vv-3_mv0_ngaussian.wav
# Saved: female_009_musdb_bg_16_p-2_vv0_mv-5_ngaussian.wav
# Saved: female_009_musdb_bg_16_p-2_vv0_mv-3_ngaussian.wav
# Saved: female_009_musdb_bg_16_p-2_vv0_mv0_ngaussian.wav
# Saved: female_009_musdb_bg_16_p-2_vv3_mv-5_ngaussian.wav
# Saved: female_009_musdb_bg_16_p-2_vv3_mv-3_ngaussian.wav
# Saved: female_009_musdb_bg_16_p-2_vv3_mv0_ngaussian.wav
# Saved: female_009_musdb_bg_16_p0_vv-3_mv-5_ngaussian.wav
# Saved: female_009_musdb_bg_16_p0_vv-3_mv-3_ngaussian.wav
# Saved: female_009_musdb_bg_16_p0_vv-3_mv0_ngaussian.wav
# Saved: female_009_musdb_bg_16_p0_vv0_mv-5_ngaussian.wav
# Saved: female_009_musdb_bg_16_p0_vv0_mv-3_ngaussian.wav
# Saved: female_009_musdb_bg_16_p0_vv0_mv0_ngaussian.wav
# Saved: female_009_musdb_bg_16_p0_vv3_mv-5_ngaussian.wav
# Saved: female_009_musdb_bg_16_p0_vv3_mv-3_ngaussian.wav
# Saved: female_009_musdb_bg_16_p0_vv3_mv0_ngaussian.wav
# Saved: female_009_musdb_bg_16_p2_vv-3_mv-5_ngaussian.wav
# Saved: female_009_musdb_bg_16_p2_vv-3_mv-3_ngaussian.wav
# Saved: female_009_musdb_bg_16_p2_vv-3_mv0_ngaussian.wav
# Saved: female_009_musdb_bg_16_p2_vv0_mv-5_ngaussian.wav
# Saved: female_009_musdb_bg_16_p2_vv0_mv-3_ngaussian.wav
# Saved: female_009_musdb_bg_16_p2_vv0_mv0_ngaussian.wav
# Saved: female_009_musdb_bg_16_p2_vv3_mv-5_ngaussian.wav
# Saved: female_009_musdb_bg_16_p2_vv3_mv-3_ngaussian.wav
# Saved: female_009_musdb_bg_16_p2_vv3_mv0_ngaussian.wav
# Saved: female_010_musdb_bg_17_p-2_vv-3_mv-5_nwhite.wav
# Saved: female_010_musdb_bg_17_p-2_vv-3_mv-3_nwhite.wav
# Saved: female_010_musdb_bg_17_p-2_vv-3_mv0_nwhite.wav
# Saved: female_010_musdb_bg_17_p-2_vv0_mv-5_nwhite.wav
# Saved: female_010_musdb_bg_17_p-2_vv0_mv-3_nwhite.wav
# Saved: female_010_musdb_bg_17_p-2_vv0_mv0_nwhite.wav
# Saved: female_010_musdb_bg_17_p-2_vv3_mv-5_nwhite.wav
# Saved: female_010_musdb_bg_17_p-2_vv3_mv-3_nwhite.wav
# Saved: female_010_musdb_bg_17_p-2_vv3_mv0_nwhite.wav
# Saved: female_010_musdb_bg_17_p0_vv-3_mv-5_nwhite.wav
# Saved: female_010_musdb_bg_17_p0_vv-3_mv-3_nwhite.wav
# Saved: female_010_musdb_bg_17_p0_vv-3_mv0_nwhite.wav
# Saved: female_010_musdb_bg_17_p0_vv0_mv-5_nwhite.wav
# Saved: female_010_musdb_bg_17_p0_vv0_mv-3_nwhite.wav
# Saved: female_010_musdb_bg_17_p0_vv0_mv0_nwhite.wav
# Saved: female_010_musdb_bg_17_p0_vv3_mv-5_nwhite.wav
# Saved: female_010_musdb_bg_17_p0_vv3_mv-3_nwhite.wav
# Saved: female_010_musdb_bg_17_p0_vv3_mv0_nwhite.wav
# Saved: female_010_musdb_bg_17_p2_vv-3_mv-5_nwhite.wav
# Saved: female_010_musdb_bg_17_p2_vv-3_mv-3_nwhite.wav
# Saved: female_010_musdb_bg_17_p2_vv-3_mv0_nwhite.wav
# Saved: female_010_musdb_bg_17_p2_vv0_mv-5_nwhite.wav
# Saved: female_010_musdb_bg_17_p2_vv0_mv-3_nwhite.wav
# Saved: female_010_musdb_bg_17_p2_vv0_mv0_nwhite.wav
# Saved: female_010_musdb_bg_17_p2_vv3_mv-5_nwhite.wav
# Saved: female_010_musdb_bg_17_p2_vv3_mv-3_nwhite.wav
# Saved: female_010_musdb_bg_17_p2_vv3_mv0_nwhite.wav
# Saved: female_011_musdb_bg_18_p-2_vv-3_mv-5_npink.wav
# Saved: female_011_musdb_bg_18_p-2_vv-3_mv-3_npink.wav
# Saved: female_011_musdb_bg_18_p-2_vv-3_mv0_npink.wav
# Saved: female_011_musdb_bg_18_p-2_vv0_mv-5_npink.wav
# Saved: female_011_musdb_bg_18_p-2_vv0_mv-3_npink.wav
# Saved: female_011_musdb_bg_18_p-2_vv0_mv0_npink.wav
# Saved: female_011_musdb_bg_18_p-2_vv3_mv-5_npink.wav
# Saved: female_011_musdb_bg_18_p-2_vv3_mv-3_npink.wav
# Saved: female_011_musdb_bg_18_p-2_vv3_mv0_npink.wav
# Saved: female_011_musdb_bg_18_p0_vv-3_mv-5_npink.wav
# Saved: female_011_musdb_bg_18_p0_vv-3_mv-3_npink.wav
# Saved: female_011_musdb_bg_18_p0_vv-3_mv0_npink.wav
# Saved: female_011_musdb_bg_18_p0_vv0_mv-5_npink.wav
# Saved: female_011_musdb_bg_18_p0_vv0_mv-3_npink.wav
# Saved: female_011_musdb_bg_18_p0_vv0_mv0_npink.wav
# Saved: female_011_musdb_bg_18_p0_vv3_mv-5_npink.wav
# Saved: female_011_musdb_bg_18_p0_vv3_mv-3_npink.wav
# Saved: female_011_musdb_bg_18_p0_vv3_mv0_npink.wav
# Saved: female_011_musdb_bg_18_p2_vv-3_mv-5_npink.wav
# Saved: female_011_musdb_bg_18_p2_vv-3_mv-3_npink.wav
# Saved: female_011_musdb_bg_18_p2_vv-3_mv0_npink.wav
# Saved: female_011_musdb_bg_18_p2_vv0_mv-5_npink.wav
# Saved: female_011_musdb_bg_18_p2_vv0_mv-3_npink.wav
# Saved: female_011_musdb_bg_18_p2_vv0_mv0_npink.wav
# Saved: female_011_musdb_bg_18_p2_vv3_mv-5_npink.wav
# Saved: female_011_musdb_bg_18_p2_vv3_mv-3_npink.wav
# Saved: female_011_musdb_bg_18_p2_vv3_mv0_npink.wav
# Saved: female_012_musdb_bg_19_p-2_vv-3_mv-5_ngaussian.wav
# Saved: female_012_musdb_bg_19_p-2_vv-3_mv-3_ngaussian.wav
# Saved: female_012_musdb_bg_19_p-2_vv-3_mv0_ngaussian.wav
# Saved: female_012_musdb_bg_19_p-2_vv0_mv-5_ngaussian.wav
# Saved: female_012_musdb_bg_19_p-2_vv0_mv-3_ngaussian.wav
# Saved: female_012_musdb_bg_19_p-2_vv0_mv0_ngaussian.wav
# Saved: female_012_musdb_bg_19_p-2_vv3_mv-5_ngaussian.wav
# Saved: female_012_musdb_bg_19_p-2_vv3_mv-3_ngaussian.wav
# Saved: female_012_musdb_bg_19_p-2_vv3_mv0_ngaussian.wav
# Saved: female_012_musdb_bg_19_p0_vv-3_mv-5_ngaussian.wav
# Saved: female_012_musdb_bg_19_p0_vv-3_mv-3_ngaussian.wav
# Saved: female_012_musdb_bg_19_p0_vv-3_mv0_ngaussian.wav
# Saved: female_012_musdb_bg_19_p0_vv0_mv-5_ngaussian.wav
# Saved: female_012_musdb_bg_19_p0_vv0_mv-3_ngaussian.wav
# Saved: female_012_musdb_bg_19_p0_vv0_mv0_ngaussian.wav
# Saved: female_012_musdb_bg_19_p0_vv3_mv-5_ngaussian.wav
# Saved: female_012_musdb_bg_19_p0_vv3_mv-3_ngaussian.wav
# Saved: female_012_musdb_bg_19_p0_vv3_mv0_ngaussian.wav
# Saved: female_012_musdb_bg_19_p2_vv-3_mv-5_ngaussian.wav
# Saved: female_012_musdb_bg_19_p2_vv-3_mv-3_ngaussian.wav
# Saved: female_012_musdb_bg_19_p2_vv-3_mv0_ngaussian.wav
# Saved: female_012_musdb_bg_19_p2_vv0_mv-5_ngaussian.wav
# Saved: female_012_musdb_bg_19_p2_vv0_mv-3_ngaussian.wav
# Saved: female_012_musdb_bg_19_p2_vv0_mv0_ngaussian.wav
# Saved: female_012_musdb_bg_19_p2_vv3_mv-5_ngaussian.wav
# Saved: female_012_musdb_bg_19_p2_vv3_mv-3_ngaussian.wav
# Saved: female_012_musdb_bg_19_p2_vv3_mv0_ngaussian.wav
# Saved: female_013_musdb_bg_2_p-2_vv-3_mv-5_nwhite.wav
# Saved: female_013_musdb_bg_2_p-2_vv-3_mv-3_nwhite.wav
# Saved: female_013_musdb_bg_2_p-2_vv-3_mv0_nwhite.wav
# Saved: female_013_musdb_bg_2_p-2_vv0_mv-5_nwhite.wav
# Saved: female_013_musdb_bg_2_p-2_vv0_mv-3_nwhite.wav
# Saved: female_013_musdb_bg_2_p-2_vv0_mv0_nwhite.wav
# Saved: female_013_musdb_bg_2_p-2_vv3_mv-5_nwhite.wav
# Saved: female_013_musdb_bg_2_p-2_vv3_mv-3_nwhite.wav
# Saved: female_013_musdb_bg_2_p-2_vv3_mv0_nwhite.wav
# Saved: female_013_musdb_bg_2_p0_vv-3_mv-5_nwhite.wav
# Saved: female_013_musdb_bg_2_p0_vv-3_mv-3_nwhite.wav
# Saved: female_013_musdb_bg_2_p0_vv-3_mv0_nwhite.wav
# Saved: female_013_musdb_bg_2_p0_vv0_mv-5_nwhite.wav
# Saved: female_013_musdb_bg_2_p0_vv0_mv-3_nwhite.wav
# Saved: female_013_musdb_bg_2_p0_vv0_mv0_nwhite.wav
# Saved: female_013_musdb_bg_2_p0_vv3_mv-5_nwhite.wav
# Saved: female_013_musdb_bg_2_p0_vv3_mv-3_nwhite.wav
# Saved: female_013_musdb_bg_2_p0_vv3_mv0_nwhite.wav
# Saved: female_013_musdb_bg_2_p2_vv-3_mv-5_nwhite.wav
# Saved: female_013_musdb_bg_2_p2_vv-3_mv-3_nwhite.wav
# Saved: female_013_musdb_bg_2_p2_vv-3_mv0_nwhite.wav
# Saved: female_013_musdb_bg_2_p2_vv0_mv-5_nwhite.wav
# Saved: female_013_musdb_bg_2_p2_vv0_mv-3_nwhite.wav
# Saved: female_013_musdb_bg_2_p2_vv0_mv0_nwhite.wav
# Saved: female_013_musdb_bg_2_p2_vv3_mv-5_nwhite.wav
# Saved: female_013_musdb_bg_2_p2_vv3_mv-3_nwhite.wav
# Saved: female_013_musdb_bg_2_p2_vv3_mv0_nwhite.wav
# Saved: female_014_musdb_bg_20_p-2_vv-3_mv-5_npink.wav
# Saved: female_014_musdb_bg_20_p-2_vv-3_mv-3_npink.wav
# Saved: female_014_musdb_bg_20_p-2_vv-3_mv0_npink.wav
# Saved: female_014_musdb_bg_20_p-2_vv0_mv-5_npink.wav
# Saved: female_014_musdb_bg_20_p-2_vv0_mv-3_npink.wav
# Saved: female_014_musdb_bg_20_p-2_vv0_mv0_npink.wav
# Saved: female_014_musdb_bg_20_p-2_vv3_mv-5_npink.wav
# Saved: female_014_musdb_bg_20_p-2_vv3_mv-3_npink.wav
# Saved: female_014_musdb_bg_20_p-2_vv3_mv0_npink.wav
# Saved: female_014_musdb_bg_20_p0_vv-3_mv-5_npink.wav
# Saved: female_014_musdb_bg_20_p0_vv-3_mv-3_npink.wav
# Saved: female_014_musdb_bg_20_p0_vv-3_mv0_npink.wav
# Saved: female_014_musdb_bg_20_p0_vv0_mv-5_npink.wav
# Saved: female_014_musdb_bg_20_p0_vv0_mv-3_npink.wav
# Saved: female_014_musdb_bg_20_p0_vv0_mv0_npink.wav
# Saved: female_014_musdb_bg_20_p0_vv3_mv-5_npink.wav
# Saved: female_014_musdb_bg_20_p0_vv3_mv-3_npink.wav
# Saved: female_014_musdb_bg_20_p0_vv3_mv0_npink.wav
# Saved: female_014_musdb_bg_20_p2_vv-3_mv-5_npink.wav
# Saved: female_014_musdb_bg_20_p2_vv-3_mv-3_npink.wav
# Saved: female_014_musdb_bg_20_p2_vv-3_mv0_npink.wav
# Saved: female_014_musdb_bg_20_p2_vv0_mv-5_npink.wav
# Saved: female_014_musdb_bg_20_p2_vv0_mv-3_npink.wav
# Saved: female_014_musdb_bg_20_p2_vv0_mv0_npink.wav
# Saved: female_014_musdb_bg_20_p2_vv3_mv-5_npink.wav
# Saved: female_014_musdb_bg_20_p2_vv3_mv-3_npink.wav
# Saved: female_014_musdb_bg_20_p2_vv3_mv0_npink.wav
# Saved: female_015_musdb_bg_21_p-2_vv-3_mv-5_ngaussian.wav
# Saved: female_015_musdb_bg_21_p-2_vv-3_mv-3_ngaussian.wav
# Saved: female_015_musdb_bg_21_p-2_vv-3_mv0_ngaussian.wav
# Saved: female_015_musdb_bg_21_p-2_vv0_mv-5_ngaussian.wav
# Saved: female_015_musdb_bg_21_p-2_vv0_mv-3_ngaussian.wav
# Saved: female_015_musdb_bg_21_p-2_vv0_mv0_ngaussian.wav
# Saved: female_015_musdb_bg_21_p-2_vv3_mv-5_ngaussian.wav
# Saved: female_015_musdb_bg_21_p-2_vv3_mv-3_ngaussian.wav
# Saved: female_015_musdb_bg_21_p-2_vv3_mv0_ngaussian.wav
# Saved: female_015_musdb_bg_21_p0_vv-3_mv-5_ngaussian.wav
# Saved: female_015_musdb_bg_21_p0_vv-3_mv-3_ngaussian.wav
# Saved: female_015_musdb_bg_21_p0_vv-3_mv0_ngaussian.wav
# Saved: female_015_musdb_bg_21_p0_vv0_mv-5_ngaussian.wav
# Saved: female_015_musdb_bg_21_p0_vv0_mv-3_ngaussian.wav
# Saved: female_015_musdb_bg_21_p0_vv0_mv0_ngaussian.wav
# Saved: female_015_musdb_bg_21_p0_vv3_mv-5_ngaussian.wav
# Saved: female_015_musdb_bg_21_p0_vv3_mv-3_ngaussian.wav
# Saved: female_015_musdb_bg_21_p0_vv3_mv0_ngaussian.wav
# Saved: female_015_musdb_bg_21_p2_vv-3_mv-5_ngaussian.wav
# Saved: female_015_musdb_bg_21_p2_vv-3_mv-3_ngaussian.wav
# Saved: female_015_musdb_bg_21_p2_vv-3_mv0_ngaussian.wav
# Saved: female_015_musdb_bg_21_p2_vv0_mv-5_ngaussian.wav
# Saved: female_015_musdb_bg_21_p2_vv0_mv-3_ngaussian.wav
# Saved: female_015_musdb_bg_21_p2_vv0_mv0_ngaussian.wav
# Saved: female_015_musdb_bg_21_p2_vv3_mv-5_ngaussian.wav
# Saved: female_015_musdb_bg_21_p2_vv3_mv-3_ngaussian.wav
# Saved: female_015_musdb_bg_21_p2_vv3_mv0_ngaussian.wav
# Saved: female_016_musdb_bg_22_p-2_vv-3_mv-5_nwhite.wav
# Saved: female_016_musdb_bg_22_p-2_vv-3_mv-3_nwhite.wav
# Saved: female_016_musdb_bg_22_p-2_vv-3_mv0_nwhite.wav
# Saved: female_016_musdb_bg_22_p-2_vv0_mv-5_nwhite.wav
# Saved: female_016_musdb_bg_22_p-2_vv0_mv-3_nwhite.wav
# Saved: female_016_musdb_bg_22_p-2_vv0_mv0_nwhite.wav
# Saved: female_016_musdb_bg_22_p-2_vv3_mv-5_nwhite.wav
# Saved: female_016_musdb_bg_22_p-2_vv3_mv-3_nwhite.wav
# Saved: female_016_musdb_bg_22_p-2_vv3_mv0_nwhite.wav
# Saved: female_016_musdb_bg_22_p0_vv-3_mv-5_nwhite.wav
# Saved: female_016_musdb_bg_22_p0_vv-3_mv-3_nwhite.wav
# Saved: female_016_musdb_bg_22_p0_vv-3_mv0_nwhite.wav
# Saved: female_016_musdb_bg_22_p0_vv0_mv-5_nwhite.wav
# Saved: female_016_musdb_bg_22_p0_vv0_mv-3_nwhite.wav
# Saved: female_016_musdb_bg_22_p0_vv0_mv0_nwhite.wav
# Saved: female_016_musdb_bg_22_p0_vv3_mv-5_nwhite.wav
# Saved: female_016_musdb_bg_22_p0_vv3_mv-3_nwhite.wav
# Saved: female_016_musdb_bg_22_p0_vv3_mv0_nwhite.wav
# Saved: female_016_musdb_bg_22_p2_vv-3_mv-5_nwhite.wav
# Saved: female_016_musdb_bg_22_p2_vv-3_mv-3_nwhite.wav
# Saved: female_016_musdb_bg_22_p2_vv-3_mv0_nwhite.wav
# Saved: female_016_musdb_bg_22_p2_vv0_mv-5_nwhite.wav
# Saved: female_016_musdb_bg_22_p2_vv0_mv-3_nwhite.wav
# Saved: female_016_musdb_bg_22_p2_vv0_mv0_nwhite.wav
# Saved: female_016_musdb_bg_22_p2_vv3_mv-5_nwhite.wav
# Saved: female_016_musdb_bg_22_p2_vv3_mv-3_nwhite.wav
# Saved: female_016_musdb_bg_22_p2_vv3_mv0_nwhite.wav
# Saved: female_017_musdb_bg_23_p-2_vv-3_mv-5_npink.wav
# Saved: female_017_musdb_bg_23_p-2_vv-3_mv-3_npink.wav
# Saved: female_017_musdb_bg_23_p-2_vv-3_mv0_npink.wav
# Saved: female_017_musdb_bg_23_p-2_vv0_mv-5_npink.wav
# Saved: female_017_musdb_bg_23_p-2_vv0_mv-3_npink.wav
# Saved: female_017_musdb_bg_23_p-2_vv0_mv0_npink.wav
# Saved: female_017_musdb_bg_23_p-2_vv3_mv-5_npink.wav
# Saved: female_017_musdb_bg_23_p-2_vv3_mv-3_npink.wav
# Saved: female_017_musdb_bg_23_p-2_vv3_mv0_npink.wav
# Saved: female_017_musdb_bg_23_p0_vv-3_mv-5_npink.wav
# Saved: female_017_musdb_bg_23_p0_vv-3_mv-3_npink.wav
# Saved: female_017_musdb_bg_23_p0_vv-3_mv0_npink.wav
# Saved: female_017_musdb_bg_23_p0_vv0_mv-5_npink.wav
# Saved: female_017_musdb_bg_23_p0_vv0_mv-3_npink.wav
# Saved: female_017_musdb_bg_23_p0_vv0_mv0_npink.wav
# Saved: female_017_musdb_bg_23_p0_vv3_mv-5_npink.wav
# Saved: female_017_musdb_bg_23_p0_vv3_mv-3_npink.wav
# Saved: female_017_musdb_bg_23_p0_vv3_mv0_npink.wav
# Saved: female_017_musdb_bg_23_p2_vv-3_mv-5_npink.wav
# Saved: female_017_musdb_bg_23_p2_vv-3_mv-3_npink.wav
# Saved: female_017_musdb_bg_23_p2_vv-3_mv0_npink.wav
# Saved: female_017_musdb_bg_23_p2_vv0_mv-5_npink.wav
# Saved: female_017_musdb_bg_23_p2_vv0_mv-3_npink.wav
# Saved: female_017_musdb_bg_23_p2_vv0_mv0_npink.wav
# Saved: female_017_musdb_bg_23_p2_vv3_mv-5_npink.wav
# Saved: female_017_musdb_bg_23_p2_vv3_mv-3_npink.wav
# Saved: female_017_musdb_bg_23_p2_vv3_mv0_npink.wav
# Saved: female_018_musdb_bg_24_p-2_vv-3_mv-5_ngaussian.wav
# Saved: female_018_musdb_bg_24_p-2_vv-3_mv-3_ngaussian.wav
# Saved: female_018_musdb_bg_24_p-2_vv-3_mv0_ngaussian.wav
# Saved: female_018_musdb_bg_24_p-2_vv0_mv-5_ngaussian.wav
# Saved: female_018_musdb_bg_24_p-2_vv0_mv-3_ngaussian.wav
# Saved: female_018_musdb_bg_24_p-2_vv0_mv0_ngaussian.wav
# Saved: female_018_musdb_bg_24_p-2_vv3_mv-5_ngaussian.wav
# Saved: female_018_musdb_bg_24_p-2_vv3_mv-3_ngaussian.wav
# Saved: female_018_musdb_bg_24_p-2_vv3_mv0_ngaussian.wav
# Saved: female_018_musdb_bg_24_p0_vv-3_mv-5_ngaussian.wav
# Saved: female_018_musdb_bg_24_p0_vv-3_mv-3_ngaussian.wav
# Saved: female_018_musdb_bg_24_p0_vv-3_mv0_ngaussian.wav
# Saved: female_018_musdb_bg_24_p0_vv0_mv-5_ngaussian.wav
# Saved: female_018_musdb_bg_24_p0_vv0_mv-3_ngaussian.wav
# Saved: female_018_musdb_bg_24_p0_vv0_mv0_ngaussian.wav
# Saved: female_018_musdb_bg_24_p0_vv3_mv-5_ngaussian.wav
# Saved: female_018_musdb_bg_24_p0_vv3_mv-3_ngaussian.wav
# Saved: female_018_musdb_bg_24_p0_vv3_mv0_ngaussian.wav
# Saved: female_018_musdb_bg_24_p2_vv-3_mv-5_ngaussian.wav
# Saved: female_018_musdb_bg_24_p2_vv-3_mv-3_ngaussian.wav
# Saved: female_018_musdb_bg_24_p2_vv-3_mv0_ngaussian.wav
# Saved: female_018_musdb_bg_24_p2_vv0_mv-5_ngaussian.wav
# Saved: female_018_musdb_bg_24_p2_vv0_mv-3_ngaussian.wav
# Saved: female_018_musdb_bg_24_p2_vv0_mv0_ngaussian.wav
# Saved: female_018_musdb_bg_24_p2_vv3_mv-5_ngaussian.wav
# Saved: female_018_musdb_bg_24_p2_vv3_mv-3_ngaussian.wav
# Saved: female_018_musdb_bg_24_p2_vv3_mv0_ngaussian.wav
# Saved: female_019_musdb_bg_25_p-2_vv-3_mv-5_nwhite.wav
# Saved: female_019_musdb_bg_25_p-2_vv-3_mv-3_nwhite.wav
# Saved: female_019_musdb_bg_25_p-2_vv-3_mv0_nwhite.wav
# Saved: female_019_musdb_bg_25_p-2_vv0_mv-5_nwhite.wav
# Saved: female_019_musdb_bg_25_p-2_vv0_mv-3_nwhite.wav
# Saved: female_019_musdb_bg_25_p-2_vv0_mv0_nwhite.wav
# Saved: female_019_musdb_bg_25_p-2_vv3_mv-5_nwhite.wav
# Saved: female_019_musdb_bg_25_p-2_vv3_mv-3_nwhite.wav
# Saved: female_019_musdb_bg_25_p-2_vv3_mv0_nwhite.wav
# Saved: female_019_musdb_bg_25_p0_vv-3_mv-5_nwhite.wav
# Saved: female_019_musdb_bg_25_p0_vv-3_mv-3_nwhite.wav
# Saved: female_019_musdb_bg_25_p0_vv-3_mv0_nwhite.wav
# Saved: female_019_musdb_bg_25_p0_vv0_mv-5_nwhite.wav
# Saved: female_019_musdb_bg_25_p0_vv0_mv-3_nwhite.wav
# Saved: female_019_musdb_bg_25_p0_vv0_mv0_nwhite.wav
# Saved: female_019_musdb_bg_25_p0_vv3_mv-5_nwhite.wav
# Saved: female_019_musdb_bg_25_p0_vv3_mv-3_nwhite.wav
# Saved: female_019_musdb_bg_25_p0_vv3_mv0_nwhite.wav
# Saved: female_019_musdb_bg_25_p2_vv-3_mv-5_nwhite.wav
# Saved: female_019_musdb_bg_25_p2_vv-3_mv-3_nwhite.wav
# Saved: female_019_musdb_bg_25_p2_vv-3_mv0_nwhite.wav
# Saved: female_019_musdb_bg_25_p2_vv0_mv-5_nwhite.wav
# Saved: female_019_musdb_bg_25_p2_vv0_mv-3_nwhite.wav
# Saved: female_019_musdb_bg_25_p2_vv0_mv0_nwhite.wav
# Saved: female_019_musdb_bg_25_p2_vv3_mv-5_nwhite.wav
# Saved: female_019_musdb_bg_25_p2_vv3_mv-3_nwhite.wav
# Saved: female_019_musdb_bg_25_p2_vv3_mv0_nwhite.wav
# Saved: female_020_musdb_bg_26_p-2_vv-3_mv-5_npink.wav
# Saved: female_020_musdb_bg_26_p-2_vv-3_mv-3_npink.wav
# Saved: female_020_musdb_bg_26_p-2_vv-3_mv0_npink.wav
# Saved: female_020_musdb_bg_26_p-2_vv0_mv-5_npink.wav
# Saved: female_020_musdb_bg_26_p-2_vv0_mv-3_npink.wav
# Saved: female_020_musdb_bg_26_p-2_vv0_mv0_npink.wav
# Saved: female_020_musdb_bg_26_p-2_vv3_mv-5_npink.wav
# Saved: female_020_musdb_bg_26_p-2_vv3_mv-3_npink.wav
# Saved: female_020_musdb_bg_26_p-2_vv3_mv0_npink.wav
# Saved: female_020_musdb_bg_26_p0_vv-3_mv-5_npink.wav
# Saved: female_020_musdb_bg_26_p0_vv-3_mv-3_npink.wav
# Saved: female_020_musdb_bg_26_p0_vv-3_mv0_npink.wav
# Saved: female_020_musdb_bg_26_p0_vv0_mv-5_npink.wav
# Saved: female_020_musdb_bg_26_p0_vv0_mv-3_npink.wav
# Saved: female_020_musdb_bg_26_p0_vv0_mv0_npink.wav
# Saved: female_020_musdb_bg_26_p0_vv3_mv-5_npink.wav
# Saved: female_020_musdb_bg_26_p0_vv3_mv-3_npink.wav
# Saved: female_020_musdb_bg_26_p0_vv3_mv0_npink.wav
# Saved: female_020_musdb_bg_26_p2_vv-3_mv-5_npink.wav
# Saved: female_020_musdb_bg_26_p2_vv-3_mv-3_npink.wav
# Saved: female_020_musdb_bg_26_p2_vv-3_mv0_npink.wav
# Saved: female_020_musdb_bg_26_p2_vv0_mv-5_npink.wav
# Saved: female_020_musdb_bg_26_p2_vv0_mv-3_npink.wav
# Saved: female_020_musdb_bg_26_p2_vv0_mv0_npink.wav
# Saved: female_020_musdb_bg_26_p2_vv3_mv-5_npink.wav
# Saved: female_020_musdb_bg_26_p2_vv3_mv-3_npink.wav
# Saved: female_020_musdb_bg_26_p2_vv3_mv0_npink.wav
# Saved: male_001_musdb_bg_27_p-2_vv-3_mv-5_ngaussian.wav
# Saved: male_001_musdb_bg_27_p-2_vv-3_mv-3_ngaussian.wav
# Saved: male_001_musdb_bg_27_p-2_vv-3_mv0_ngaussian.wav
# Saved: male_001_musdb_bg_27_p-2_vv0_mv-5_ngaussian.wav
# Saved: male_001_musdb_bg_27_p-2_vv0_mv-3_ngaussian.wav
# Saved: male_001_musdb_bg_27_p-2_vv0_mv0_ngaussian.wav
# Saved: male_001_musdb_bg_27_p-2_vv3_mv-5_ngaussian.wav
# Saved: male_001_musdb_bg_27_p-2_vv3_mv-3_ngaussian.wav
# Saved: male_001_musdb_bg_27_p-2_vv3_mv0_ngaussian.wav
# Saved: male_001_musdb_bg_27_p0_vv-3_mv-5_ngaussian.wav
# Saved: male_001_musdb_bg_27_p0_vv-3_mv-3_ngaussian.wav
# Saved: male_001_musdb_bg_27_p0_vv-3_mv0_ngaussian.wav
# Saved: male_001_musdb_bg_27_p0_vv0_mv-5_ngaussian.wav
# Saved: male_001_musdb_bg_27_p0_vv0_mv-3_ngaussian.wav
# Saved: male_001_musdb_bg_27_p0_vv0_mv0_ngaussian.wav
# Saved: male_001_musdb_bg_27_p0_vv3_mv-5_ngaussian.wav
# Saved: male_001_musdb_bg_27_p0_vv3_mv-3_ngaussian.wav
# Saved: male_001_musdb_bg_27_p0_vv3_mv0_ngaussian.wav
# Saved: male_001_musdb_bg_27_p2_vv-3_mv-5_ngaussian.wav
# Saved: male_001_musdb_bg_27_p2_vv-3_mv-3_ngaussian.wav
# Saved: male_001_musdb_bg_27_p2_vv-3_mv0_ngaussian.wav
# Saved: male_001_musdb_bg_27_p2_vv0_mv-5_ngaussian.wav
# Saved: male_001_musdb_bg_27_p2_vv0_mv-3_ngaussian.wav
# Saved: male_001_musdb_bg_27_p2_vv0_mv0_ngaussian.wav
# Saved: male_001_musdb_bg_27_p2_vv3_mv-5_ngaussian.wav
# Saved: male_001_musdb_bg_27_p2_vv3_mv-3_ngaussian.wav
# Saved: male_001_musdb_bg_27_p2_vv3_mv0_ngaussian.wav
# Saved: male_002_musdb_bg_28_p-2_vv-3_mv-5_nwhite.wav
# Saved: male_002_musdb_bg_28_p-2_vv-3_mv-3_nwhite.wav
# Saved: male_002_musdb_bg_28_p-2_vv-3_mv0_nwhite.wav
# Saved: male_002_musdb_bg_28_p-2_vv0_mv-5_nwhite.wav
# Saved: male_002_musdb_bg_28_p-2_vv0_mv-3_nwhite.wav
# Saved: male_002_musdb_bg_28_p-2_vv0_mv0_nwhite.wav
# Saved: male_002_musdb_bg_28_p-2_vv3_mv-5_nwhite.wav
# Saved: male_002_musdb_bg_28_p-2_vv3_mv-3_nwhite.wav
# Saved: male_002_musdb_bg_28_p-2_vv3_mv0_nwhite.wav
# Saved: male_002_musdb_bg_28_p0_vv-3_mv-5_nwhite.wav
# Saved: male_002_musdb_bg_28_p0_vv-3_mv-3_nwhite.wav
# Saved: male_002_musdb_bg_28_p0_vv-3_mv0_nwhite.wav
# Saved: male_002_musdb_bg_28_p0_vv0_mv-5_nwhite.wav
# Saved: male_002_musdb_bg_28_p0_vv0_mv-3_nwhite.wav
# Saved: male_002_musdb_bg_28_p0_vv0_mv0_nwhite.wav
# Saved: male_002_musdb_bg_28_p0_vv3_mv-5_nwhite.wav
# Saved: male_002_musdb_bg_28_p0_vv3_mv-3_nwhite.wav
# Saved: male_002_musdb_bg_28_p0_vv3_mv0_nwhite.wav
# Saved: male_002_musdb_bg_28_p2_vv-3_mv-5_nwhite.wav
# Saved: male_002_musdb_bg_28_p2_vv-3_mv-3_nwhite.wav
# Saved: male_002_musdb_bg_28_p2_vv-3_mv0_nwhite.wav
# Saved: male_002_musdb_bg_28_p2_vv0_mv-5_nwhite.wav
# Saved: male_002_musdb_bg_28_p2_vv0_mv-3_nwhite.wav
# Saved: male_002_musdb_bg_28_p2_vv0_mv0_nwhite.wav
# Saved: male_002_musdb_bg_28_p2_vv3_mv-5_nwhite.wav
# Saved: male_002_musdb_bg_28_p2_vv3_mv-3_nwhite.wav
# Saved: male_002_musdb_bg_28_p2_vv3_mv0_nwhite.wav
# Saved: male_003_musdb_bg_29_p-2_vv-3_mv-5_npink.wav
# Saved: male_003_musdb_bg_29_p-2_vv-3_mv-3_npink.wav
# Saved: male_003_musdb_bg_29_p-2_vv-3_mv0_npink.wav
# Saved: male_003_musdb_bg_29_p-2_vv0_mv-5_npink.wav
# Saved: male_003_musdb_bg_29_p-2_vv0_mv-3_npink.wav
# Saved: male_003_musdb_bg_29_p-2_vv0_mv0_npink.wav
# Saved: male_003_musdb_bg_29_p-2_vv3_mv-5_npink.wav
# Saved: male_003_musdb_bg_29_p-2_vv3_mv-3_npink.wav
# Saved: male_003_musdb_bg_29_p-2_vv3_mv0_npink.wav
# Saved: male_003_musdb_bg_29_p0_vv-3_mv-5_npink.wav
# Saved: male_003_musdb_bg_29_p0_vv-3_mv-3_npink.wav
# Saved: male_003_musdb_bg_29_p0_vv-3_mv0_npink.wav
# Saved: male_003_musdb_bg_29_p0_vv0_mv-5_npink.wav
# Saved: male_003_musdb_bg_29_p0_vv0_mv-3_npink.wav
# Saved: male_003_musdb_bg_29_p0_vv0_mv0_npink.wav
# Saved: male_003_musdb_bg_29_p0_vv3_mv-5_npink.wav
# Saved: male_003_musdb_bg_29_p0_vv3_mv-3_npink.wav
# Saved: male_003_musdb_bg_29_p0_vv3_mv0_npink.wav
# Saved: male_003_musdb_bg_29_p2_vv-3_mv-5_npink.wav
# Saved: male_003_musdb_bg_29_p2_vv-3_mv-3_npink.wav
# Saved: male_003_musdb_bg_29_p2_vv-3_mv0_npink.wav
# Saved: male_003_musdb_bg_29_p2_vv0_mv-5_npink.wav
# Saved: male_003_musdb_bg_29_p2_vv0_mv-3_npink.wav
# Saved: male_003_musdb_bg_29_p2_vv0_mv0_npink.wav
# Saved: male_003_musdb_bg_29_p2_vv3_mv-5_npink.wav
# Saved: male_003_musdb_bg_29_p2_vv3_mv-3_npink.wav
# Saved: male_003_musdb_bg_29_p2_vv3_mv0_npink.wav
# Saved: male_004_musdb_bg_3_p-2_vv-3_mv-5_ngaussian.wav
# Saved: male_004_musdb_bg_3_p-2_vv-3_mv-3_ngaussian.wav
# Saved: male_004_musdb_bg_3_p-2_vv-3_mv0_ngaussian.wav
# Saved: male_004_musdb_bg_3_p-2_vv0_mv-5_ngaussian.wav
# Saved: male_004_musdb_bg_3_p-2_vv0_mv-3_ngaussian.wav
# Saved: male_004_musdb_bg_3_p-2_vv0_mv0_ngaussian.wav
# Saved: male_004_musdb_bg_3_p-2_vv3_mv-5_ngaussian.wav
# Saved: male_004_musdb_bg_3_p-2_vv3_mv-3_ngaussian.wav
# Saved: male_004_musdb_bg_3_p-2_vv3_mv0_ngaussian.wav
# Saved: male_004_musdb_bg_3_p0_vv-3_mv-5_ngaussian.wav
# Saved: male_004_musdb_bg_3_p0_vv-3_mv-3_ngaussian.wav
# Saved: male_004_musdb_bg_3_p0_vv-3_mv0_ngaussian.wav
# Saved: male_004_musdb_bg_3_p0_vv0_mv-5_ngaussian.wav
# Saved: male_004_musdb_bg_3_p0_vv0_mv-3_ngaussian.wav
# Saved: male_004_musdb_bg_3_p0_vv0_mv0_ngaussian.wav
# Saved: male_004_musdb_bg_3_p0_vv3_mv-5_ngaussian.wav
# Saved: male_004_musdb_bg_3_p0_vv3_mv-3_ngaussian.wav
# Saved: male_004_musdb_bg_3_p0_vv3_mv0_ngaussian.wav
# Saved: male_004_musdb_bg_3_p2_vv-3_mv-5_ngaussian.wav
# Saved: male_004_musdb_bg_3_p2_vv-3_mv-3_ngaussian.wav
# Saved: male_004_musdb_bg_3_p2_vv-3_mv0_ngaussian.wav
# Saved: male_004_musdb_bg_3_p2_vv0_mv-5_ngaussian.wav
# Saved: male_004_musdb_bg_3_p2_vv0_mv-3_ngaussian.wav
# Saved: male_004_musdb_bg_3_p2_vv0_mv0_ngaussian.wav
# Saved: male_004_musdb_bg_3_p2_vv3_mv-5_ngaussian.wav
# Saved: male_004_musdb_bg_3_p2_vv3_mv-3_ngaussian.wav
# Saved: male_004_musdb_bg_3_p2_vv3_mv0_ngaussian.wav
# Saved: male_005_musdb_bg_30_p-2_vv-3_mv-5_nwhite.wav
# Saved: male_005_musdb_bg_30_p-2_vv-3_mv-3_nwhite.wav
# Saved: male_005_musdb_bg_30_p-2_vv-3_mv0_nwhite.wav
# Saved: male_005_musdb_bg_30_p-2_vv0_mv-5_nwhite.wav
# Saved: male_005_musdb_bg_30_p-2_vv0_mv-3_nwhite.wav
# Saved: male_005_musdb_bg_30_p-2_vv0_mv0_nwhite.wav
# Saved: male_005_musdb_bg_30_p-2_vv3_mv-5_nwhite.wav
# Saved: male_005_musdb_bg_30_p-2_vv3_mv-3_nwhite.wav
# Saved: male_005_musdb_bg_30_p-2_vv3_mv0_nwhite.wav
# Saved: male_005_musdb_bg_30_p0_vv-3_mv-5_nwhite.wav
# Saved: male_005_musdb_bg_30_p0_vv-3_mv-3_nwhite.wav
# Saved: male_005_musdb_bg_30_p0_vv-3_mv0_nwhite.wav
# Saved: male_005_musdb_bg_30_p0_vv0_mv-5_nwhite.wav
# Saved: male_005_musdb_bg_30_p0_vv0_mv-3_nwhite.wav
# Saved: male_005_musdb_bg_30_p0_vv0_mv0_nwhite.wav
# Saved: male_005_musdb_bg_30_p0_vv3_mv-5_nwhite.wav
# Saved: male_005_musdb_bg_30_p0_vv3_mv-3_nwhite.wav
# Saved: male_005_musdb_bg_30_p0_vv3_mv0_nwhite.wav
# Saved: male_005_musdb_bg_30_p2_vv-3_mv-5_nwhite.wav
# Saved: male_005_musdb_bg_30_p2_vv-3_mv-3_nwhite.wav
# Saved: male_005_musdb_bg_30_p2_vv-3_mv0_nwhite.wav
# Saved: male_005_musdb_bg_30_p2_vv0_mv-5_nwhite.wav
# Saved: male_005_musdb_bg_30_p2_vv0_mv-3_nwhite.wav
# Saved: male_005_musdb_bg_30_p2_vv0_mv0_nwhite.wav
# Saved: male_005_musdb_bg_30_p2_vv3_mv-5_nwhite.wav
# Saved: male_005_musdb_bg_30_p2_vv3_mv-3_nwhite.wav
# Saved: male_005_musdb_bg_30_p2_vv3_mv0_nwhite.wav
# Saved: male_006_musdb_bg_31_p-2_vv-3_mv-5_npink.wav
# Saved: male_006_musdb_bg_31_p-2_vv-3_mv-3_npink.wav
# Saved: male_006_musdb_bg_31_p-2_vv-3_mv0_npink.wav
# Saved: male_006_musdb_bg_31_p-2_vv0_mv-5_npink.wav
# Saved: male_006_musdb_bg_31_p-2_vv0_mv-3_npink.wav
# Saved: male_006_musdb_bg_31_p-2_vv0_mv0_npink.wav
# Saved: male_006_musdb_bg_31_p-2_vv3_mv-5_npink.wav
# Saved: male_006_musdb_bg_31_p-2_vv3_mv-3_npink.wav
# Saved: male_006_musdb_bg_31_p-2_vv3_mv0_npink.wav
# Saved: male_006_musdb_bg_31_p0_vv-3_mv-5_npink.wav
# Saved: male_006_musdb_bg_31_p0_vv-3_mv-3_npink.wav
# Saved: male_006_musdb_bg_31_p0_vv-3_mv0_npink.wav
# Saved: male_006_musdb_bg_31_p0_vv0_mv-5_npink.wav
# Saved: male_006_musdb_bg_31_p0_vv0_mv-3_npink.wav
# Saved: male_006_musdb_bg_31_p0_vv0_mv0_npink.wav
# Saved: male_006_musdb_bg_31_p0_vv3_mv-5_npink.wav
# Saved: male_006_musdb_bg_31_p0_vv3_mv-3_npink.wav
# Saved: male_006_musdb_bg_31_p0_vv3_mv0_npink.wav
# Saved: male_006_musdb_bg_31_p2_vv-3_mv-5_npink.wav
# Saved: male_006_musdb_bg_31_p2_vv-3_mv-3_npink.wav
# Saved: male_006_musdb_bg_31_p2_vv-3_mv0_npink.wav
# Saved: male_006_musdb_bg_31_p2_vv0_mv-5_npink.wav
# Saved: male_006_musdb_bg_31_p2_vv0_mv-3_npink.wav
# Saved: male_006_musdb_bg_31_p2_vv0_mv0_npink.wav
# Saved: male_006_musdb_bg_31_p2_vv3_mv-5_npink.wav
# Saved: male_006_musdb_bg_31_p2_vv3_mv-3_npink.wav
# Saved: male_006_musdb_bg_31_p2_vv3_mv0_npink.wav
# Saved: male_007_musdb_bg_32_p-2_vv-3_mv-5_ngaussian.wav
# Saved: male_007_musdb_bg_32_p-2_vv-3_mv-3_ngaussian.wav
# Saved: male_007_musdb_bg_32_p-2_vv-3_mv0_ngaussian.wav
# Saved: male_007_musdb_bg_32_p-2_vv0_mv-5_ngaussian.wav
# Saved: male_007_musdb_bg_32_p-2_vv0_mv-3_ngaussian.wav
# Saved: male_007_musdb_bg_32_p-2_vv0_mv0_ngaussian.wav
# Saved: male_007_musdb_bg_32_p-2_vv3_mv-5_ngaussian.wav
# Saved: male_007_musdb_bg_32_p-2_vv3_mv-3_ngaussian.wav
# Saved: male_007_musdb_bg_32_p-2_vv3_mv0_ngaussian.wav
# Saved: male_007_musdb_bg_32_p0_vv-3_mv-5_ngaussian.wav
# Saved: male_007_musdb_bg_32_p0_vv-3_mv-3_ngaussian.wav
# Saved: male_007_musdb_bg_32_p0_vv-3_mv0_ngaussian.wav
# Saved: male_007_musdb_bg_32_p0_vv0_mv-5_ngaussian.wav
# Saved: male_007_musdb_bg_32_p0_vv0_mv-3_ngaussian.wav
# Saved: male_007_musdb_bg_32_p0_vv0_mv0_ngaussian.wav
# Saved: male_007_musdb_bg_32_p0_vv3_mv-5_ngaussian.wav
# Saved: male_007_musdb_bg_32_p0_vv3_mv-3_ngaussian.wav
# Saved: male_007_musdb_bg_32_p0_vv3_mv0_ngaussian.wav
# Saved: male_007_musdb_bg_32_p2_vv-3_mv-5_ngaussian.wav
# Saved: male_007_musdb_bg_32_p2_vv-3_mv-3_ngaussian.wav
# Saved: male_007_musdb_bg_32_p2_vv-3_mv0_ngaussian.wav
# Saved: male_007_musdb_bg_32_p2_vv0_mv-5_ngaussian.wav
# Saved: male_007_musdb_bg_32_p2_vv0_mv-3_ngaussian.wav
# Saved: male_007_musdb_bg_32_p2_vv0_mv0_ngaussian.wav
# Saved: male_007_musdb_bg_32_p2_vv3_mv-5_ngaussian.wav
# Saved: male_007_musdb_bg_32_p2_vv3_mv-3_ngaussian.wav
# Saved: male_007_musdb_bg_32_p2_vv3_mv0_ngaussian.wav
# Saved: male_008_musdb_bg_33_p-2_vv-3_mv-5_nwhite.wav
# Saved: male_008_musdb_bg_33_p-2_vv-3_mv-3_nwhite.wav
# Saved: male_008_musdb_bg_33_p-2_vv-3_mv0_nwhite.wav
# Saved: male_008_musdb_bg_33_p-2_vv0_mv-5_nwhite.wav
# Saved: male_008_musdb_bg_33_p-2_vv0_mv-3_nwhite.wav
# Saved: male_008_musdb_bg_33_p-2_vv0_mv0_nwhite.wav
# Saved: male_008_musdb_bg_33_p-2_vv3_mv-5_nwhite.wav
# Saved: male_008_musdb_bg_33_p-2_vv3_mv-3_nwhite.wav
# Saved: male_008_musdb_bg_33_p-2_vv3_mv0_nwhite.wav
# Saved: male_008_musdb_bg_33_p0_vv-3_mv-5_nwhite.wav
# Saved: male_008_musdb_bg_33_p0_vv-3_mv-3_nwhite.wav
# Saved: male_008_musdb_bg_33_p0_vv-3_mv0_nwhite.wav
# Saved: male_008_musdb_bg_33_p0_vv0_mv-5_nwhite.wav
# Saved: male_008_musdb_bg_33_p0_vv0_mv-3_nwhite.wav
# Saved: male_008_musdb_bg_33_p0_vv0_mv0_nwhite.wav
# Saved: male_008_musdb_bg_33_p0_vv3_mv-5_nwhite.wav
# Saved: male_008_musdb_bg_33_p0_vv3_mv-3_nwhite.wav
# Saved: male_008_musdb_bg_33_p0_vv3_mv0_nwhite.wav
# Saved: male_008_musdb_bg_33_p2_vv-3_mv-5_nwhite.wav
# Saved: male_008_musdb_bg_33_p2_vv-3_mv-3_nwhite.wav
# Saved: male_008_musdb_bg_33_p2_vv-3_mv0_nwhite.wav
# Saved: male_008_musdb_bg_33_p2_vv0_mv-5_nwhite.wav
# Saved: male_008_musdb_bg_33_p2_vv0_mv-3_nwhite.wav
# Saved: male_008_musdb_bg_33_p2_vv0_mv0_nwhite.wav
# Saved: male_008_musdb_bg_33_p2_vv3_mv-5_nwhite.wav
# Saved: male_008_musdb_bg_33_p2_vv3_mv-3_nwhite.wav
# Saved: male_008_musdb_bg_33_p2_vv3_mv0_nwhite.wav
# Saved: male_009_musdb_bg_34_p-2_vv-3_mv-5_npink.wav
# Saved: male_009_musdb_bg_34_p-2_vv-3_mv-3_npink.wav
# Saved: male_009_musdb_bg_34_p-2_vv-3_mv0_npink.wav
# Saved: male_009_musdb_bg_34_p-2_vv0_mv-5_npink.wav
# Saved: male_009_musdb_bg_34_p-2_vv0_mv-3_npink.wav
# Saved: male_009_musdb_bg_34_p-2_vv0_mv0_npink.wav
# Saved: male_009_musdb_bg_34_p-2_vv3_mv-5_npink.wav
# Saved: male_009_musdb_bg_34_p-2_vv3_mv-3_npink.wav
# Saved: male_009_musdb_bg_34_p-2_vv3_mv0_npink.wav
# Saved: male_009_musdb_bg_34_p0_vv-3_mv-5_npink.wav
# Saved: male_009_musdb_bg_34_p0_vv-3_mv-3_npink.wav
# Saved: male_009_musdb_bg_34_p0_vv-3_mv0_npink.wav
# Saved: male_009_musdb_bg_34_p0_vv0_mv-5_npink.wav
# Saved: male_009_musdb_bg_34_p0_vv0_mv-3_npink.wav
# Saved: male_009_musdb_bg_34_p0_vv0_mv0_npink.wav
# Saved: male_009_musdb_bg_34_p0_vv3_mv-5_npink.wav
# Saved: male_009_musdb_bg_34_p0_vv3_mv-3_npink.wav
# Saved: male_009_musdb_bg_34_p0_vv3_mv0_npink.wav
# Saved: male_009_musdb_bg_34_p2_vv-3_mv-5_npink.wav
# Saved: male_009_musdb_bg_34_p2_vv-3_mv-3_npink.wav
# Saved: male_009_musdb_bg_34_p2_vv-3_mv0_npink.wav
# Saved: male_009_musdb_bg_34_p2_vv0_mv-5_npink.wav
# Saved: male_009_musdb_bg_34_p2_vv0_mv-3_npink.wav
# Saved: male_009_musdb_bg_34_p2_vv0_mv0_npink.wav
# Saved: male_009_musdb_bg_34_p2_vv3_mv-5_npink.wav
# Saved: male_009_musdb_bg_34_p2_vv3_mv-3_npink.wav
# Saved: male_009_musdb_bg_34_p2_vv3_mv0_npink.wav
# Saved: male_010_musdb_bg_35_p-2_vv-3_mv-5_ngaussian.wav
# Saved: male_010_musdb_bg_35_p-2_vv-3_mv-3_ngaussian.wav
# Saved: male_010_musdb_bg_35_p-2_vv-3_mv0_ngaussian.wav
# Saved: male_010_musdb_bg_35_p-2_vv0_mv-5_ngaussian.wav
# Saved: male_010_musdb_bg_35_p-2_vv0_mv-3_ngaussian.wav
# Saved: male_010_musdb_bg_35_p-2_vv0_mv0_ngaussian.wav
# Saved: male_010_musdb_bg_35_p-2_vv3_mv-5_ngaussian.wav
# Saved: male_010_musdb_bg_35_p-2_vv3_mv-3_ngaussian.wav
# Saved: male_010_musdb_bg_35_p-2_vv3_mv0_ngaussian.wav
# Saved: male_010_musdb_bg_35_p0_vv-3_mv-5_ngaussian.wav
# Saved: male_010_musdb_bg_35_p0_vv-3_mv-3_ngaussian.wav
# Saved: male_010_musdb_bg_35_p0_vv-3_mv0_ngaussian.wav
# Saved: male_010_musdb_bg_35_p0_vv0_mv-5_ngaussian.wav
# Saved: male_010_musdb_bg_35_p0_vv0_mv-3_ngaussian.wav
# Saved: male_010_musdb_bg_35_p0_vv0_mv0_ngaussian.wav
# Saved: male_010_musdb_bg_35_p0_vv3_mv-5_ngaussian.wav
# Saved: male_010_musdb_bg_35_p0_vv3_mv-3_ngaussian.wav
# Saved: male_010_musdb_bg_35_p0_vv3_mv0_ngaussian.wav
# Saved: male_010_musdb_bg_35_p2_vv-3_mv-5_ngaussian.wav
# Saved: male_010_musdb_bg_35_p2_vv-3_mv-3_ngaussian.wav
# Saved: male_010_musdb_bg_35_p2_vv-3_mv0_ngaussian.wav
# Saved: male_010_musdb_bg_35_p2_vv0_mv-5_ngaussian.wav
# Saved: male_010_musdb_bg_35_p2_vv0_mv-3_ngaussian.wav
# Saved: male_010_musdb_bg_35_p2_vv0_mv0_ngaussian.wav
# Saved: male_010_musdb_bg_35_p2_vv3_mv-5_ngaussian.wav
# Saved: male_010_musdb_bg_35_p2_vv3_mv-3_ngaussian.wav
# Saved: male_010_musdb_bg_35_p2_vv3_mv0_ngaussian.wav
# Saved: male_011_musdb_bg_36_p-2_vv-3_mv-5_nwhite.wav
# Saved: male_011_musdb_bg_36_p-2_vv-3_mv-3_nwhite.wav
# Saved: male_011_musdb_bg_36_p-2_vv-3_mv0_nwhite.wav
# Saved: male_011_musdb_bg_36_p-2_vv0_mv-5_nwhite.wav
# Saved: male_011_musdb_bg_36_p-2_vv0_mv-3_nwhite.wav
# Saved: male_011_musdb_bg_36_p-2_vv0_mv0_nwhite.wav
# Saved: male_011_musdb_bg_36_p-2_vv3_mv-5_nwhite.wav
# Saved: male_011_musdb_bg_36_p-2_vv3_mv-3_nwhite.wav
# Saved: male_011_musdb_bg_36_p-2_vv3_mv0_nwhite.wav
# Saved: male_011_musdb_bg_36_p0_vv-3_mv-5_nwhite.wav
# Saved: male_011_musdb_bg_36_p0_vv-3_mv-3_nwhite.wav
# Saved: male_011_musdb_bg_36_p0_vv-3_mv0_nwhite.wav
# Saved: male_011_musdb_bg_36_p0_vv0_mv-5_nwhite.wav
# Saved: male_011_musdb_bg_36_p0_vv0_mv-3_nwhite.wav
# Saved: male_011_musdb_bg_36_p0_vv0_mv0_nwhite.wav
# Saved: male_011_musdb_bg_36_p0_vv3_mv-5_nwhite.wav
# Saved: male_011_musdb_bg_36_p0_vv3_mv-3_nwhite.wav
# Saved: male_011_musdb_bg_36_p0_vv3_mv0_nwhite.wav
# Saved: male_011_musdb_bg_36_p2_vv-3_mv-5_nwhite.wav
# Saved: male_011_musdb_bg_36_p2_vv-3_mv-3_nwhite.wav
# Saved: male_011_musdb_bg_36_p2_vv-3_mv0_nwhite.wav
# Saved: male_011_musdb_bg_36_p2_vv0_mv-5_nwhite.wav
# Saved: male_011_musdb_bg_36_p2_vv0_mv-3_nwhite.wav
# Saved: male_011_musdb_bg_36_p2_vv0_mv0_nwhite.wav
# Saved: male_011_musdb_bg_36_p2_vv3_mv-5_nwhite.wav
# Saved: male_011_musdb_bg_36_p2_vv3_mv-3_nwhite.wav
# Saved: male_011_musdb_bg_36_p2_vv3_mv0_nwhite.wav
# Saved: male_012_musdb_bg_37_p-2_vv-3_mv-5_npink.wav
# Saved: male_012_musdb_bg_37_p-2_vv-3_mv-3_npink.wav
# Saved: male_012_musdb_bg_37_p-2_vv-3_mv0_npink.wav
# Saved: male_012_musdb_bg_37_p-2_vv0_mv-5_npink.wav
# Saved: male_012_musdb_bg_37_p-2_vv0_mv-3_npink.wav
# Saved: male_012_musdb_bg_37_p-2_vv0_mv0_npink.wav
# Saved: male_012_musdb_bg_37_p-2_vv3_mv-5_npink.wav
# Saved: male_012_musdb_bg_37_p-2_vv3_mv-3_npink.wav
# Saved: male_012_musdb_bg_37_p-2_vv3_mv0_npink.wav
# Saved: male_012_musdb_bg_37_p0_vv-3_mv-5_npink.wav
# Saved: male_012_musdb_bg_37_p0_vv-3_mv-3_npink.wav
# Saved: male_012_musdb_bg_37_p0_vv-3_mv0_npink.wav
# Saved: male_012_musdb_bg_37_p0_vv0_mv-5_npink.wav
# Saved: male_012_musdb_bg_37_p0_vv0_mv-3_npink.wav
# Saved: male_012_musdb_bg_37_p0_vv0_mv0_npink.wav
# Saved: male_012_musdb_bg_37_p0_vv3_mv-5_npink.wav
# Saved: male_012_musdb_bg_37_p0_vv3_mv-3_npink.wav
# Saved: male_012_musdb_bg_37_p0_vv3_mv0_npink.wav
# Saved: male_012_musdb_bg_37_p2_vv-3_mv-5_npink.wav
# Saved: male_012_musdb_bg_37_p2_vv-3_mv-3_npink.wav
# Saved: male_012_musdb_bg_37_p2_vv-3_mv0_npink.wav
# Saved: male_012_musdb_bg_37_p2_vv0_mv-5_npink.wav
# Saved: male_012_musdb_bg_37_p2_vv0_mv-3_npink.wav
# Saved: male_012_musdb_bg_37_p2_vv0_mv0_npink.wav
# Saved: male_012_musdb_bg_37_p2_vv3_mv-5_npink.wav
# Saved: male_012_musdb_bg_37_p2_vv3_mv-3_npink.wav
# Saved: male_012_musdb_bg_37_p2_vv3_mv0_npink.wav
# Saved: male_013_musdb_bg_38_p-2_vv-3_mv-5_ngaussian.wav
# Saved: male_013_musdb_bg_38_p-2_vv-3_mv-3_ngaussian.wav
# Saved: male_013_musdb_bg_38_p-2_vv-3_mv0_ngaussian.wav
# Saved: male_013_musdb_bg_38_p-2_vv0_mv-5_ngaussian.wav
# Saved: male_013_musdb_bg_38_p-2_vv0_mv-3_ngaussian.wav
# Saved: male_013_musdb_bg_38_p-2_vv0_mv0_ngaussian.wav
# Saved: male_013_musdb_bg_38_p-2_vv3_mv-5_ngaussian.wav
# Saved: male_013_musdb_bg_38_p-2_vv3_mv-3_ngaussian.wav
# Saved: male_013_musdb_bg_38_p-2_vv3_mv0_ngaussian.wav
# Saved: male_013_musdb_bg_38_p0_vv-3_mv-5_ngaussian.wav
# Saved: male_013_musdb_bg_38_p0_vv-3_mv-3_ngaussian.wav
# Saved: male_013_musdb_bg_38_p0_vv-3_mv0_ngaussian.wav
# Saved: male_013_musdb_bg_38_p0_vv0_mv-5_ngaussian.wav
# Saved: male_013_musdb_bg_38_p0_vv0_mv-3_ngaussian.wav
# Saved: male_013_musdb_bg_38_p0_vv0_mv0_ngaussian.wav
# Saved: male_013_musdb_bg_38_p0_vv3_mv-5_ngaussian.wav
# Saved: male_013_musdb_bg_38_p0_vv3_mv-3_ngaussian.wav
# Saved: male_013_musdb_bg_38_p0_vv3_mv0_ngaussian.wav
# Saved: male_013_musdb_bg_38_p2_vv-3_mv-5_ngaussian.wav
# Saved: male_013_musdb_bg_38_p2_vv-3_mv-3_ngaussian.wav
# Saved: male_013_musdb_bg_38_p2_vv-3_mv0_ngaussian.wav
# Saved: male_013_musdb_bg_38_p2_vv0_mv-5_ngaussian.wav
# Saved: male_013_musdb_bg_38_p2_vv0_mv-3_ngaussian.wav
# Saved: male_013_musdb_bg_38_p2_vv0_mv0_ngaussian.wav
# Saved: male_013_musdb_bg_38_p2_vv3_mv-5_ngaussian.wav
# Saved: male_013_musdb_bg_38_p2_vv3_mv-3_ngaussian.wav
# Saved: male_013_musdb_bg_38_p2_vv3_mv0_ngaussian.wav
# Saved: male_014_musdb_bg_39_p-2_vv-3_mv-5_nwhite.wav
# Saved: male_014_musdb_bg_39_p-2_vv-3_mv-3_nwhite.wav
# Saved: male_014_musdb_bg_39_p-2_vv-3_mv0_nwhite.wav
# Saved: male_014_musdb_bg_39_p-2_vv0_mv-5_nwhite.wav
# Saved: male_014_musdb_bg_39_p-2_vv0_mv-3_nwhite.wav
# Saved: male_014_musdb_bg_39_p-2_vv0_mv0_nwhite.wav
# Saved: male_014_musdb_bg_39_p-2_vv3_mv-5_nwhite.wav
# Saved: male_014_musdb_bg_39_p-2_vv3_mv-3_nwhite.wav
# Saved: male_014_musdb_bg_39_p-2_vv3_mv0_nwhite.wav
# Saved: male_014_musdb_bg_39_p0_vv-3_mv-5_nwhite.wav
# Saved: male_014_musdb_bg_39_p0_vv-3_mv-3_nwhite.wav
# Saved: male_014_musdb_bg_39_p0_vv-3_mv0_nwhite.wav
# Saved: male_014_musdb_bg_39_p0_vv0_mv-5_nwhite.wav
# Saved: male_014_musdb_bg_39_p0_vv0_mv-3_nwhite.wav
# Saved: male_014_musdb_bg_39_p0_vv0_mv0_nwhite.wav
# Saved: male_014_musdb_bg_39_p0_vv3_mv-5_nwhite.wav
# Saved: male_014_musdb_bg_39_p0_vv3_mv-3_nwhite.wav
# Saved: male_014_musdb_bg_39_p0_vv3_mv0_nwhite.wav
# Saved: male_014_musdb_bg_39_p2_vv-3_mv-5_nwhite.wav
# Saved: male_014_musdb_bg_39_p2_vv-3_mv-3_nwhite.wav
# Saved: male_014_musdb_bg_39_p2_vv-3_mv0_nwhite.wav
# Saved: male_014_musdb_bg_39_p2_vv0_mv-5_nwhite.wav
# Saved: male_014_musdb_bg_39_p2_vv0_mv-3_nwhite.wav
# Saved: male_014_musdb_bg_39_p2_vv0_mv0_nwhite.wav
# Saved: male_014_musdb_bg_39_p2_vv3_mv-5_nwhite.wav
# Saved: male_014_musdb_bg_39_p2_vv3_mv-3_nwhite.wav
# Saved: male_014_musdb_bg_39_p2_vv3_mv0_nwhite.wav
# Saved: male_015_musdb_bg_4_p-2_vv-3_mv-5_npink.wav
# Saved: male_015_musdb_bg_4_p-2_vv-3_mv-3_npink.wav
# Saved: male_015_musdb_bg_4_p-2_vv-3_mv0_npink.wav
# Saved: male_015_musdb_bg_4_p-2_vv0_mv-5_npink.wav
# Saved: male_015_musdb_bg_4_p-2_vv0_mv-3_npink.wav
# Saved: male_015_musdb_bg_4_p-2_vv0_mv0_npink.wav
# Saved: male_015_musdb_bg_4_p-2_vv3_mv-5_npink.wav
# Saved: male_015_musdb_bg_4_p-2_vv3_mv-3_npink.wav
# Saved: male_015_musdb_bg_4_p-2_vv3_mv0_npink.wav
# Saved: male_015_musdb_bg_4_p0_vv-3_mv-5_npink.wav
# Saved: male_015_musdb_bg_4_p0_vv-3_mv-3_npink.wav
# Saved: male_015_musdb_bg_4_p0_vv-3_mv0_npink.wav
# Saved: male_015_musdb_bg_4_p0_vv0_mv-5_npink.wav
# Saved: male_015_musdb_bg_4_p0_vv0_mv-3_npink.wav
# Saved: male_015_musdb_bg_4_p0_vv0_mv0_npink.wav
# Saved: male_015_musdb_bg_4_p0_vv3_mv-5_npink.wav
# Saved: male_015_musdb_bg_4_p0_vv3_mv-3_npink.wav
# Saved: male_015_musdb_bg_4_p0_vv3_mv0_npink.wav
# Saved: male_015_musdb_bg_4_p2_vv-3_mv-5_npink.wav
# Saved: male_015_musdb_bg_4_p2_vv-3_mv-3_npink.wav
# Saved: male_015_musdb_bg_4_p2_vv-3_mv0_npink.wav
# Saved: male_015_musdb_bg_4_p2_vv0_mv-5_npink.wav
# Saved: male_015_musdb_bg_4_p2_vv0_mv-3_npink.wav
# Saved: male_015_musdb_bg_4_p2_vv0_mv0_npink.wav
# Saved: male_015_musdb_bg_4_p2_vv3_mv-5_npink.wav
# Saved: male_015_musdb_bg_4_p2_vv3_mv-3_npink.wav
# Saved: male_015_musdb_bg_4_p2_vv3_mv0_npink.wav
# Saved: male_016_musdb_bg_40_p-2_vv-3_mv-5_ngaussian.wav
# Saved: male_016_musdb_bg_40_p-2_vv-3_mv-3_ngaussian.wav
# Saved: male_016_musdb_bg_40_p-2_vv-3_mv0_ngaussian.wav
# Saved: male_016_musdb_bg_40_p-2_vv0_mv-5_ngaussian.wav
# Saved: male_016_musdb_bg_40_p-2_vv0_mv-3_ngaussian.wav
# Saved: male_016_musdb_bg_40_p-2_vv0_mv0_ngaussian.wav
# Saved: male_016_musdb_bg_40_p-2_vv3_mv-5_ngaussian.wav
# Saved: male_016_musdb_bg_40_p-2_vv3_mv-3_ngaussian.wav
# Saved: male_016_musdb_bg_40_p-2_vv3_mv0_ngaussian.wav
# Saved: male_016_musdb_bg_40_p0_vv-3_mv-5_ngaussian.wav
# Saved: male_016_musdb_bg_40_p0_vv-3_mv-3_ngaussian.wav
# Saved: male_016_musdb_bg_40_p0_vv-3_mv0_ngaussian.wav
# Saved: male_016_musdb_bg_40_p0_vv0_mv-5_ngaussian.wav
# Saved: male_016_musdb_bg_40_p0_vv0_mv-3_ngaussian.wav
# Saved: male_016_musdb_bg_40_p0_vv0_mv0_ngaussian.wav
# Saved: male_016_musdb_bg_40_p0_vv3_mv-5_ngaussian.wav
# Saved: male_016_musdb_bg_40_p0_vv3_mv-3_ngaussian.wav
# Saved: male_016_musdb_bg_40_p0_vv3_mv0_ngaussian.wav
# Saved: male_016_musdb_bg_40_p2_vv-3_mv-5_ngaussian.wav
# Saved: male_016_musdb_bg_40_p2_vv-3_mv-3_ngaussian.wav
# Saved: male_016_musdb_bg_40_p2_vv-3_mv0_ngaussian.wav
# Saved: male_016_musdb_bg_40_p2_vv0_mv-5_ngaussian.wav
# Saved: male_016_musdb_bg_40_p2_vv0_mv-3_ngaussian.wav
# Saved: male_016_musdb_bg_40_p2_vv0_mv0_ngaussian.wav
# Saved: male_016_musdb_bg_40_p2_vv3_mv-5_ngaussian.wav
# Saved: male_016_musdb_bg_40_p2_vv3_mv-3_ngaussian.wav
# Saved: male_016_musdb_bg_40_p2_vv3_mv0_ngaussian.wav
# Saved: male_017_musdb_bg_41_p-2_vv-3_mv-5_nwhite.wav
# Saved: male_017_musdb_bg_41_p-2_vv-3_mv-3_nwhite.wav
# Saved: male_017_musdb_bg_41_p-2_vv-3_mv0_nwhite.wav
# Saved: male_017_musdb_bg_41_p-2_vv0_mv-5_nwhite.wav
# Saved: male_017_musdb_bg_41_p-2_vv0_mv-3_nwhite.wav
# Saved: male_017_musdb_bg_41_p-2_vv0_mv0_nwhite.wav
# Saved: male_017_musdb_bg_41_p-2_vv3_mv-5_nwhite.wav
# Saved: male_017_musdb_bg_41_p-2_vv3_mv-3_nwhite.wav
# Saved: male_017_musdb_bg_41_p-2_vv3_mv0_nwhite.wav
# Saved: male_017_musdb_bg_41_p0_vv-3_mv-5_nwhite.wav
# Saved: male_017_musdb_bg_41_p0_vv-3_mv-3_nwhite.wav
# Saved: male_017_musdb_bg_41_p0_vv-3_mv0_nwhite.wav
# Saved: male_017_musdb_bg_41_p0_vv0_mv-5_nwhite.wav
# Saved: male_017_musdb_bg_41_p0_vv0_mv-3_nwhite.wav
# Saved: male_017_musdb_bg_41_p0_vv0_mv0_nwhite.wav
# Saved: male_017_musdb_bg_41_p0_vv3_mv-5_nwhite.wav
# Saved: male_017_musdb_bg_41_p0_vv3_mv-3_nwhite.wav
# Saved: male_017_musdb_bg_41_p0_vv3_mv0_nwhite.wav
# Saved: male_017_musdb_bg_41_p2_vv-3_mv-5_nwhite.wav
# Saved: male_017_musdb_bg_41_p2_vv-3_mv-3_nwhite.wav
# Saved: male_017_musdb_bg_41_p2_vv-3_mv0_nwhite.wav
# Saved: male_017_musdb_bg_41_p2_vv0_mv-5_nwhite.wav
# Saved: male_017_musdb_bg_41_p2_vv0_mv-3_nwhite.wav
# Saved: male_017_musdb_bg_41_p2_vv0_mv0_nwhite.wav
# Saved: male_017_musdb_bg_41_p2_vv3_mv-5_nwhite.wav
# Saved: male_017_musdb_bg_41_p2_vv3_mv-3_nwhite.wav
# Saved: male_017_musdb_bg_41_p2_vv3_mv0_nwhite.wav
# Saved: male_018_musdb_bg_42_p-2_vv-3_mv-5_npink.wav
# Saved: male_018_musdb_bg_42_p-2_vv-3_mv-3_npink.wav
# Saved: male_018_musdb_bg_42_p-2_vv-3_mv0_npink.wav
# Saved: male_018_musdb_bg_42_p-2_vv0_mv-5_npink.wav
# Saved: male_018_musdb_bg_42_p-2_vv0_mv-3_npink.wav
# Saved: male_018_musdb_bg_42_p-2_vv0_mv0_npink.wav
# Saved: male_018_musdb_bg_42_p-2_vv3_mv-5_npink.wav
# Saved: male_018_musdb_bg_42_p-2_vv3_mv-3_npink.wav
# Saved: male_018_musdb_bg_42_p-2_vv3_mv0_npink.wav
# Saved: male_018_musdb_bg_42_p0_vv-3_mv-5_npink.wav
# Saved: male_018_musdb_bg_42_p0_vv-3_mv-3_npink.wav
# Saved: male_018_musdb_bg_42_p0_vv-3_mv0_npink.wav
# Saved: male_018_musdb_bg_42_p0_vv0_mv-5_npink.wav
# Saved: male_018_musdb_bg_42_p0_vv0_mv-3_npink.wav
# Saved: male_018_musdb_bg_42_p0_vv0_mv0_npink.wav
# Saved: male_018_musdb_bg_42_p0_vv3_mv-5_npink.wav
# Saved: male_018_musdb_bg_42_p0_vv3_mv-3_npink.wav
# Saved: male_018_musdb_bg_42_p0_vv3_mv0_npink.wav
# Saved: male_018_musdb_bg_42_p2_vv-3_mv-5_npink.wav
# Saved: male_018_musdb_bg_42_p2_vv-3_mv-3_npink.wav
# Saved: male_018_musdb_bg_42_p2_vv-3_mv0_npink.wav
# Saved: male_018_musdb_bg_42_p2_vv0_mv-5_npink.wav
# Saved: male_018_musdb_bg_42_p2_vv0_mv-3_npink.wav
# Saved: male_018_musdb_bg_42_p2_vv0_mv0_npink.wav
# Saved: male_018_musdb_bg_42_p2_vv3_mv-5_npink.wav
# Saved: male_018_musdb_bg_42_p2_vv3_mv-3_npink.wav
# Saved: male_018_musdb_bg_42_p2_vv3_mv0_npink.wav
# Saved: male_019_musdb_bg_43_p-2_vv-3_mv-5_ngaussian.wav
# Saved: male_019_musdb_bg_43_p-2_vv-3_mv-3_ngaussian.wav
# Saved: male_019_musdb_bg_43_p-2_vv-3_mv0_ngaussian.wav
# Saved: male_019_musdb_bg_43_p-2_vv0_mv-5_ngaussian.wav
# Saved: male_019_musdb_bg_43_p-2_vv0_mv-3_ngaussian.wav
# Saved: male_019_musdb_bg_43_p-2_vv0_mv0_ngaussian.wav
# Saved: male_019_musdb_bg_43_p-2_vv3_mv-5_ngaussian.wav
# Saved: male_019_musdb_bg_43_p-2_vv3_mv-3_ngaussian.wav
# Saved: male_019_musdb_bg_43_p-2_vv3_mv0_ngaussian.wav
# Saved: male_019_musdb_bg_43_p0_vv-3_mv-5_ngaussian.wav
# Saved: male_019_musdb_bg_43_p0_vv-3_mv-3_ngaussian.wav
# Saved: male_019_musdb_bg_43_p0_vv-3_mv0_ngaussian.wav
# Saved: male_019_musdb_bg_43_p0_vv0_mv-5_ngaussian.wav
# Saved: male_019_musdb_bg_43_p0_vv0_mv-3_ngaussian.wav
# Saved: male_019_musdb_bg_43_p0_vv0_mv0_ngaussian.wav
# Saved: male_019_musdb_bg_43_p0_vv3_mv-5_ngaussian.wav
# Saved: male_019_musdb_bg_43_p0_vv3_mv-3_ngaussian.wav
# Saved: male_019_musdb_bg_43_p0_vv3_mv0_ngaussian.wav
# Saved: male_019_musdb_bg_43_p2_vv-3_mv-5_ngaussian.wav
# Saved: male_019_musdb_bg_43_p2_vv-3_mv-3_ngaussian.wav
# Saved: male_019_musdb_bg_43_p2_vv-3_mv0_ngaussian.wav
# Saved: male_019_musdb_bg_43_p2_vv0_mv-5_ngaussian.wav
# Saved: male_019_musdb_bg_43_p2_vv0_mv-3_ngaussian.wav
# Saved: male_019_musdb_bg_43_p2_vv0_mv0_ngaussian.wav
# Saved: male_019_musdb_bg_43_p2_vv3_mv-5_ngaussian.wav
# Saved: male_019_musdb_bg_43_p2_vv3_mv-3_ngaussian.wav
# Saved: male_019_musdb_bg_43_p2_vv3_mv0_ngaussian.wav
# Saved: male_020_musdb_bg_44_p-2_vv-3_mv-5_nwhite.wav
# Saved: male_020_musdb_bg_44_p-2_vv-3_mv-3_nwhite.wav
# Saved: male_020_musdb_bg_44_p-2_vv-3_mv0_nwhite.wav
# Saved: male_020_musdb_bg_44_p-2_vv0_mv-5_nwhite.wav
# Saved: male_020_musdb_bg_44_p-2_vv0_mv-3_nwhite.wav
# Saved: male_020_musdb_bg_44_p-2_vv0_mv0_nwhite.wav
# Saved: male_020_musdb_bg_44_p-2_vv3_mv-5_nwhite.wav
# Saved: male_020_musdb_bg_44_p-2_vv3_mv-3_nwhite.wav
# Saved: male_020_musdb_bg_44_p-2_vv3_mv0_nwhite.wav
# Saved: male_020_musdb_bg_44_p0_vv-3_mv-5_nwhite.wav
# Saved: male_020_musdb_bg_44_p0_vv-3_mv-3_nwhite.wav
# Saved: male_020_musdb_bg_44_p0_vv-3_mv0_nwhite.wav
# Saved: male_020_musdb_bg_44_p0_vv0_mv-5_nwhite.wav
# Saved: male_020_musdb_bg_44_p0_vv0_mv-3_nwhite.wav
# Saved: male_020_musdb_bg_44_p0_vv0_mv0_nwhite.wav
# Saved: male_020_musdb_bg_44_p0_vv3_mv-5_nwhite.wav
# Saved: male_020_musdb_bg_44_p0_vv3_mv-3_nwhite.wav
# Saved: male_020_musdb_bg_44_p0_vv3_mv0_nwhite.wav
# Saved: male_020_musdb_bg_44_p2_vv-3_mv-5_nwhite.wav
# Saved: male_020_musdb_bg_44_p2_vv-3_mv-3_nwhite.wav
# Saved: male_020_musdb_bg_44_p2_vv-3_mv0_nwhite.wav
# Saved: male_020_musdb_bg_44_p2_vv0_mv-5_nwhite.wav
# Saved: male_020_musdb_bg_44_p2_vv0_mv-3_nwhite.wav
# Saved: male_020_musdb_bg_44_p2_vv0_mv0_nwhite.wav
# Saved: male_020_musdb_bg_44_p2_vv3_mv-5_nwhite.wav
# Saved: male_020_musdb_bg_44_p2_vv3_mv-3_nwhite.wav
# Saved: male_020_musdb_bg_44_p2_vv3_mv0_nwhite.wav
# Augmentation completed & saved to Google Drive!

# %%
import os

def count_wav_files(folder, extension=".wav"):
    count = sum(1 for root, _, files in os.walk(folder) for file in files if file.endswith(extension))
    return count

folder_path = "/content/drive/MyDrive/Augmented - Audios"
num_wav_files = count_wav_files(folder_path)

print(f"Number of WAV files: {num_wav_files}")
# Out:
# Number of WAV files: 1080

# %%
import os
import shutil

# Define original folders
clean_vocals_folder = "/content/drive/MyDrive/New/Clean-vocals"
background_music_folder = "/content/drive/MyDrive/CP/MUSDB18_Instrumentals"
mixed_audio_folder = "/content/drive/MyDrive/Augmented - Audios"

# Define new dataset structure
dataset_root = "/content/drive/MyDrive/New/Demucs_Training_Dataset"
train_path = os.path.join(dataset_root, "train")
valid_path = os.path.join(dataset_root, "valid")

# Create necessary directories
for subset in ["train", "valid"]:
    for category in ["mixture", "vocals", "background_music"]:
        os.makedirs(os.path.join(dataset_root, subset, category), exist_ok=True)

# Get sorted lists of files
clean_vocals = sorted(os.listdir(clean_vocals_folder))
background_music = sorted(os.listdir(background_music_folder))
mixed_audio = sorted(os.listdir(mixed_audio_folder))

# Split dataset (80% Train, 20% Validation)
split_index = int(len(mixed_audio) * 0.8)

# Function to move files
def move_files(files, src_folder, dest_folder, prefix):
    for i, file in enumerate(files):
        src_path = os.path.join(src_folder, file)
        dst_path = os.path.join(dest_folder, f"{prefix}_{i:03d}.wav")  # Rename to consistent format
        shutil.copy(src_path, dst_path)

# Move files into train & valid sets
move_files(mixed_audio[:split_index], mixed_audio_folder, os.path.join(train_path, "mixture"), "track")
move_files(clean_vocals[:split_index], clean_vocals_folder, os.path.join(train_path, "vocals"), "track")
move_files(background_music[:split_index], background_music_folder, os.path.join(train_path, "background_music"), "track")

move_files(mixed_audio[split_index:], mixed_audio_folder, os.path.join(valid_path, "mixture"), "track")
move_files(clean_vocals[split_index:], clean_vocals_folder, os.path.join(valid_path, "vocals"), "track")
move_files(background_music[split_index:], background_music_folder, os.path.join(valid_path, "background_music"), "track")

print("✅ Dataset structured for Demucs training!")
# Out:
# ✅ Dataset structured for Demucs training!
